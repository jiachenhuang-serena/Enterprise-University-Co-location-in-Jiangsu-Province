# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Statistical tests
from scipy.stats import skew, kurtosis, shapiro

# Coordinate transformation and distance calculation
from pyproj import Transformer
from scipy.spatial.distance import cdist
import math

from statsmodels.stats.diagnostic import het_breuschpagan

# %%
df = pd.read_excel("company-university-2.xlsx")

print("Initial data overview:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Initial data overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50703 entries, 0 to 50702
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   number_of_patents                          50703 non-null  int64
#  1   city                                       50703 non-null  object
#  2   county                                     50703 non-null  object
#  3   national_industry_category(GB standard)    50703 non-null  object
#  4   date                                       50703 non-null  object
#  5   insured_population                         50703 non-null  int64
#  6   x_utm                                      50703 non-null  float64
#  7   y_utm                                      50703 non-null  float64
#  8   nearest_university_name                    50703 non-null  object
#  9   nearest_university_distance_m              50703 non-null  float64
#  10  double_world_class                         50703 non-null  int64
#  11  Undergraduate University                   50703 non-null  object
#  12  distance_to_nearest_bachelor_university_m  50703 non-null  float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 5.0+ MB
#
# Missing values:
# number_of_patents                            0
# city                                         0
# county                                       0
# national_industry_category(GB standard)      0
# date                                         0
# insured_population                           0
# x_utm                                        0
# y_utm                                        0
# nearest_university_name                      0
# nearest_university_distance_m                0
# double_world_class                           0
# Undergraduate University                     0
# distance_to_nearest_bachelor_university_m    0
# dtype: int64

# %%
# Convert establishment date to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Calculate firm age in years
today = pd.Timestamp.today()
df['enterprise_age'] = (today - df['date']).dt.days / 365.25

# Display age range
print(f"Firm age computed: range {df['enterprise_age'].min():.1f} ~ {df['enterprise_age'].max():.1f} years")
# Out:
# Firm age computed: range 2.1 ~ 69.1 years

# %%
# Define the order of industry categories with 'Manufacturing' as the baseline (first)
industry_order = [
    'Manufacturing',  # Baseline category
    'Agriculture and Related Activities',
    'Other Services',
    'R&D and IT Services',
    'Trade, Construction, and Business Services',
    'Utilities and Infrastructure'
]

# Convert the industry column to a categorical type with specified order
df['national_industry_category(GB standard)'] = pd.Categorical(
    df['national_industry_category(GB standard)'],
    categories=industry_order,
    ordered=True
)

# Create dummy variables, dropping the first category ('Manufacturing') as the baseline
df = pd.get_dummies(df, columns=['national_industry_category(GB standard)'], drop_first=True)

# Rename dummy variable columns for clarity
df.rename(columns={
    'national_industry_category(GB standard)_Agriculture and Related Activities': 'industry_agriculture',
    'national_industry_category(GB standard)_Other Services': 'industry_other_services',
    'national_industry_category(GB standard)_R&D and IT Services': 'industry_rnd_it',
    'national_industry_category(GB standard)_Trade, Construction, and Business Services': 'industry_trade_construction_business',
    'national_industry_category(GB standard)_Utilities and Infrastructure': 'industry_utilities'
}, inplace=True)

# Define the list of dummy variable columns (excluding the baseline)
industry_cols = [
    'industry_agriculture',
    'industry_other_services',
    'industry_rnd_it',
    'industry_trade_construction_business',
    'industry_utilities'
]

print(f"Industry dummy variables created (baseline = 'Manufacturing'): {industry_cols}")
# Out:
# Industry dummy variables created (baseline = 'Manufacturing'): ['industry_agriculture', 'industry_other_services', 'industry_rnd_it', 'industry_trade_construction_business', 'industry_utilities']

# %%
# Descriptive statistics and correlation
num_vars = [
    'nearest_university_distance_m', 'distance_to_nearest_bachelor_university_m', 'insured_population',
    'number_of_patents', 'enterprise_age'
]

print("\nDescriptive statistics of numerical variables:")
print(df[num_vars].describe())

# Correlation matrix
corr_matrix = df[num_vars].corr()
print("\nCorrelation matrix:")
print(corr_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

corr_matrix.to_csv("correlation_matrix.csv")
# Out:
# Descriptive statistics of numerical variables:
#        nearest_university_distance_m  \
# count                   50703.000000
# mean                     7680.099548
# std                      7182.750760
# min                         0.000000
# 25%                      2940.405296
# 50%                      5799.470238
# 75%                     10021.172824
# max                     67104.606431
#
#        distance_to_nearest_bachelor_university_m  insured_population  \
# count                               50703.000000        50703.000000
# mean                                12159.868918           98.207187
# std                                 12068.021355          509.095731
# min                                    20.146359            0.000000
# 25%                                  4280.933947           10.000000
# 50%                                  8992.690249           27.000000
# 75%                                 14690.024024           72.000000
# max                                 89181.436448        54532.000000
#
#        number_of_patents  enterprise_age
# count       50703.000000    50703.000000
# mean           67.626728       13.265453
# std           265.746057        7.427880
# min             0.000000        2.105407
# 25%            20.000000        7.490760
# 50%            37.000000       11.389459
# 75%            66.000000       17.995893
# max         36808.000000       69.103354
#
# Correlation matrix:
#                                            nearest_university_distance_m  \
# nearest_university_distance_m                                   1.000000
# distance_to_nearest_bachelor_university_m                       0.692723
# insured_population                                             -0.004814
# number_of_patents                                              -0.018656
# enterprise_age                                                  0.019963
#
#                                            distance_to_nearest_bachelor_university_m  \
# nearest_university_distance_m                                               0.692723
# distance_to_nearest_bachelor_university_m                                   1.000000
# insured_population                                                         -0.003769
# number_of_patents                                                          -0.015460
# enterprise_age                                                             -0.003564
#
#                                            insured_population  \
# nearest_university_distance_m                       -0.004814
# distance_to_nearest_bachelor_university_m           -0.003769
# insured_population                                   1.000000
# number_of_patents                                    0.315728
# enterprise_age                                       0.116155
#
#                                            number_of_patents  enterprise_age
# nearest_university_distance_m                      -0.018656        0.019963
# distance_to_nearest_bachelor_university_m          -0.015460       -0.003564
# insured_population                                  0.315728        0.116155
# number_of_patents                                   1.000000        0.130413
# enterprise_age                                      0.130413        1.000000

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['nearest_university_distance_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['nearest_university_distance_m'])
dist_kurt = kurtosis(df['nearest_university_distance_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['nearest_university_distance_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])
    y1_var = "log_nearest_university_distance_m"
else:
    y1_var = "nearest_university_distance_m"
# Out:
# Skewness of `distance`: 2.62
# Kurtosis of `distance`: 10.61
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 50703.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['distance_to_nearest_bachelor_university_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['distance_to_nearest_bachelor_university_m'])
dist_kurt = kurtosis(df['distance_to_nearest_bachelor_university_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['distance_to_nearest_bachelor_university_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])
    y2_var = "log_distance_to_nearest_bachelor_university_m"
else:
    y2_var = "distance_to_nearest_bachelor_university_m"
# Out:
# Skewness of `distance`: 2.29
# Kurtosis of `distance`: 6.46
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 50703.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Define variable list
variables = ['insured_population', 'number_of_patents', 'enterprise_age']

# Plot distributions
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Original distribution
    plt.subplot(3, 2, 2*i+1)
    sns.histplot(df[var].dropna(), bins=30, kde=True)
    plt.title(f"Distribution of {var}")

    # log1p-transformed distribution
    plt.subplot(3, 2, 2*i+2)
    sns.histplot(np.log1p(df[var].dropna()), bins=30, kde=True)
    plt.title(f"Distribution of log1p({var})")

plt.tight_layout()
plt.show()

# %%
# Apply log(1 + x) transformation to reduce skewness and handle zeros safely
df['log_number_of_patents'] = np.log1p(df['number_of_patents'])
df['log_insured_population'] = np.log1p(df['insured_population'])
df['log_enterprise_age'] = np.log1p(df['enterprise_age'])

# %%
# Standardize numerical independent variables
std_vars = [
    'log_insured_population', 'log_number_of_patents', 'log_enterprise_age'
]
scaler = StandardScaler()
df[std_vars] = scaler.fit_transform(df[std_vars])

# %%
# Define y and prepare X for VIF

# Use log-transformed distance as the dependent variable
df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])  # log(1 + x) avoids log(0)
y1 = df['nearest_university_distance_m']  #  this is the new target variable
# Use log-transformed distance as the dependent variable
df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])  # log(1 + x) avoids log(0)
y2 = df['distance_to_nearest_bachelor_university_m']  #  this is the new target variable

# Combine standardized numeric variables and industry dummies
X_vars = std_vars + industry_cols + ['double_world_class']
X = df[X_vars]

# %%
X
# Out:
#        log_insured_population  log_number_of_patents  log_enterprise_age  \
# 0                    1.879162               2.066303           -0.017666
# 1                    2.324572               1.998893            2.176789
# 2                    2.673746               3.424067            1.852461
# 3                    1.811518               2.715237            2.150897
# 4                    2.299908               1.857913            1.779527
# ...                       ...                    ...                 ...
# 50698               -1.799186              -3.098875           -1.306734
# 50699               -2.267661              -3.098875           -1.673919
# 50700               -2.267661              -3.098875           -1.193590
# 50701               -2.267661              -3.098875           -2.333318
# 50702               -2.267661              -3.098875           -2.173434
#
#        industry_agriculture  industry_other_services  industry_rnd_it  \
# 0                     False                    False             True
# 1                     False                    False             True
# 2                     False                    False            False
# 3                     False                    False            False
# 4                     False                    False             True
# ...                     ...                      ...              ...
# 50698                 False                    False             True
# 50699                 False                    False             True
# 50700                 False                    False             True
# 50701                 False                    False             True
# 50702                 False                    False             True
#
#        industry_trade_construction_business  industry_utilities  \
# 0                                     False               False
# 1                                     False               False
# 2                                     False               False
# 3                                     False               False
# 4                                     False               False
# ...                                     ...                 ...
# 50698                                 False               False
# 50699                                 False               False
# 50700                                 False               False
# 50701                                 False               False
# 50702                                 False               False
#
#        double_world_class
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 50698                   0
# 50699                   0
# 50700                   0
# 50701                   0
# 50702                   0
#
# [50703 rows x 9 columns]

# %%
print("\n X column data types:")
print(X.dtypes)
# Out:
#  X column data types:
# log_insured_population                  float64
# log_number_of_patents                   float64
# log_enterprise_age                      float64
# industry_agriculture                       bool
# industry_other_services                    bool
# industry_rnd_it                            bool
# industry_trade_construction_business       bool
# industry_utilities                         bool
# double_world_class                        int64
# dtype: object

# %%
# Construct the squared term of log-transformed number of patents
df['log_patent_sq'] = df['log_number_of_patents'] ** 2

# %%
X_vars = std_vars + industry_cols + ['double_world_class'] + ['log_patent_sq']
X = df[X_vars]

# %%
X = df[X_vars].copy()
X = X.astype(float)

# %%
# VIF calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("\n Variance Inflation Factors (VIF):")
print(vif_df)
# Out:
#  Variance Inflation Factors (VIF):
#                                 feature       VIF
# 0                log_insured_population  1.629148
# 1                 log_number_of_patents  1.871834
# 2                    log_enterprise_age  1.382227
# 3                  industry_agriculture  1.001045
# 4               industry_other_services  1.006442
# 5                       industry_rnd_it  1.415731
# 6  industry_trade_construction_business  1.030099
# 7                    industry_utilities  1.002950
# 8                    double_world_class  1.100480
# 9                         log_patent_sq  1.378495

# %%
# Combine all independent variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define regression formula with city fixed effects
formula1 = 'log_nearest_university_distance_m ~ ' + ' + '.join(all_vars) + ' + C(city , Treatment(reference="NanJing"))'

# Fit the OLS regression model
model1 = smf.ols(formula=formula1, data=df).fit()
print(model1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.231
# Model:                                           OLS   Adj. R-squared:                  0.230
# Method:                                Least Squares   F-statistic:                     690.7
# Date:                               Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       10:27:50   Log-Likelihood:                -62440.
# No. Observations:                              50703   AIC:                         1.249e+05
# Df Residuals:                                  50680   BIC:                         1.251e+05
# Df Model:                                         22
# Covariance Type:                           nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.1809      0.012    685.267      0.000       8.158       8.204
# industry_agriculture[T.True]                              -0.0709      0.097     -0.729      0.466      -0.262       0.120
# industry_other_services[T.True]                           -0.4468      0.086     -5.225      0.000      -0.614      -0.279
# industry_rnd_it[T.True]                                   -0.3999      0.009    -44.535      0.000      -0.417      -0.382
# industry_trade_construction_business[T.True]              -0.2700      0.015    -17.993      0.000      -0.299      -0.241
# industry_utilities[T.True]                                -0.2332      0.042     -5.539      0.000      -0.316      -0.151
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.4821      0.016     31.002      0.000       0.452       0.513
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          0.9580      0.030     31.949      0.000       0.899       1.017
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     0.7066      0.033     21.458      0.000       0.642       0.771
# C(city, Treatment(reference="NanJing"))[T.NanTong]         0.6452      0.017     37.812      0.000       0.612       0.679
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.1857      0.030     38.982      0.000       1.126       1.245
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6516      0.012     53.545      0.000       0.628       0.675
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1741      0.021     56.066      0.000       1.133       1.215
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.5978      0.014     41.845      0.000       0.570       0.626
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          0.5019      0.024     20.642      0.000       0.454       0.550
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.3241      0.020     67.168      0.000       1.285       1.363
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.8961      0.020     44.640      0.000       0.857       0.935
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.5507      0.024     23.126      0.000       0.504       0.597
# log_insured_population                                    -0.0532      0.005    -11.245      0.000      -0.063      -0.044
# log_number_of_patents                                      0.0598      0.005     11.502      0.000       0.050       0.070
# log_enterprise_age                                        -0.0501      0.004    -11.249      0.000      -0.059      -0.041
# double_world_class                                        -0.0059      0.012     -0.474      0.635      -0.030       0.019
# log_patent_sq                                             -0.0412      0.002    -20.774      0.000      -0.045      -0.037
# ==============================================================================
# Omnibus:                     3606.662   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5081.029
# Skew:                          -0.609   Prob(JB):                         0.00
# Kurtosis:                       3.961   Cond. No.                         62.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Combine all explanatory variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define the regression formula
formula2 = 'log_distance_to_nearest_bachelor_university_m ~ ' + ' + '.join(all_vars) + ' + C(city , Treatment(reference="NanJing"))'

# Fit the OLS regression model
model2 = smf.ols(formula=formula2, data=df).fit()
print(model2.summary())
# Out:
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.350
# Model:                                                       OLS   Adj. R-squared:                  0.349
# Method:                                            Least Squares   F-statistic:                     1239.
# Date:                                           Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   10:59:21   Log-Likelihood:                -61107.
# No. Observations:                                          50703   AIC:                         1.223e+05
# Df Residuals:                                              50680   BIC:                         1.225e+05
# Df Model:                                                     22
# Covariance Type:                                       nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.4598      0.012    727.500      0.000       8.437       8.483
# industry_agriculture[T.True]                               0.0271      0.095      0.286      0.775      -0.159       0.213
# industry_other_services[T.True]                           -0.4974      0.083     -5.971      0.000      -0.661      -0.334
# industry_rnd_it[T.True]                                   -0.4114      0.009    -47.043      0.000      -0.429      -0.394
# industry_trade_construction_business[T.True]              -0.2906      0.015    -19.878      0.000      -0.319      -0.262
# industry_utilities[T.True]                                -0.2938      0.041     -7.164      0.000      -0.374      -0.213
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.5525      0.015     36.477      0.000       0.523       0.582
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          1.2948      0.029     44.333      0.000       1.238       1.352
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     1.0934      0.032     34.086      0.000       1.030       1.156
# C(city, Treatment(reference="NanJing"))[T.NanTong]         1.1338      0.017     68.218      0.000       1.101       1.166
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.5648      0.030     52.814      0.000       1.507       1.623
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6863      0.012     57.899      0.000       0.663       0.710
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1912      0.020     58.400      0.000       1.151       1.231
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.8693      0.014     62.472      0.000       0.842       0.897
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          1.3505      0.024     57.020      0.000       1.304       1.397
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.7680      0.019     92.074      0.000       1.730       1.806
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.9815      0.020     50.194      0.000       0.943       1.020
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.9758      0.023     42.066      0.000       0.930       1.021
# log_insured_population                                    -0.0584      0.005    -12.672      0.000      -0.067      -0.049
# log_number_of_patents                                      0.0693      0.005     13.673      0.000       0.059       0.079
# log_enterprise_age                                        -0.0551      0.004    -12.720      0.000      -0.064      -0.047
# double_world_class                                        -0.3594      0.012    -29.534      0.000      -0.383      -0.336
# log_patent_sq                                             -0.0360      0.002    -18.640      0.000      -0.040      -0.032
# ==============================================================================
# Omnibus:                     5097.698   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.011
# Skew:                          -0.744   Prob(JB):                         0.00
# Kurtosis:                       4.254   Cond. No.                         62.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create side-by-side residual plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Residual plot for distance to any university
axs[0].scatter(model1.fittedvalues, model1.resid, alpha=0.5)
axs[0].axhline(0, color='red')
axs[0].set_title("Residual Plot - Any University")
axs[0].set_xlabel("Fitted Values")
axs[0].set_ylabel("Residuals")

# Residual plot for distance to nearest bachelor-level university
axs[1].scatter(model2.fittedvalues, model2.resid, alpha=0.5)
axs[1].axhline(0, color='red')
axs[1].set_title("Residual Plot - Bachelor-level University")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Residuals")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Extract residuals and design matrix from the model
resid = model1.resid
exog = model1.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 1534.9544
# p-value: 0.0000
# F-statistic: 71.9162
# F p-value: 0.0000

# %%
# Extract residuals and design matrix from the model
resid = model2.resid
exog = model2.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 3467.7469
# p-value: 0.0000
# F-statistic: 169.1200
# F p-value: 0.0000

# %%
model1_robust = model1.get_robustcov_results(cov_type='HC1')
print(model1_robust.summary())

model2_robust = model2.get_robustcov_results(cov_type='HC1')
print(model2_robust.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.231
# Model:                                           OLS   Adj. R-squared:                  0.230
# Method:                                Least Squares   F-statistic:                     586.1
# Date:                               Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       11:00:05   Log-Likelihood:                -62440.
# No. Observations:                              50703   AIC:                         1.249e+05
# Df Residuals:                                  50680   BIC:                         1.251e+05
# Df Model:                                         22
# Covariance Type:                                 HC1
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.1809      0.013    610.852      0.000       8.155       8.207
# industry_agriculture[T.True]                              -0.0709      0.117     -0.608      0.543      -0.300       0.158
# industry_other_services[T.True]                           -0.4468      0.099     -4.532      0.000      -0.640      -0.254
# industry_rnd_it[T.True]                                   -0.3999      0.009    -43.672      0.000      -0.418      -0.382
# industry_trade_construction_business[T.True]              -0.2700      0.015    -17.545      0.000      -0.300      -0.240
# industry_utilities[T.True]                                -0.2332      0.048     -4.855      0.000      -0.327      -0.139
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.4821      0.016     29.693      0.000       0.450       0.514
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          0.9580      0.039     24.649      0.000       0.882       1.034
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     0.7066      0.038     18.398      0.000       0.631       0.782
# C(city, Treatment(reference="NanJing"))[T.NanTong]         0.6452      0.018     35.202      0.000       0.609       0.681
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.1857      0.034     35.352      0.000       1.120       1.251
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6516      0.013     49.234      0.000       0.626       0.678
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1741      0.022     52.587      0.000       1.130       1.218
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.5978      0.014     41.266      0.000       0.569       0.626
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          0.5019      0.028     17.784      0.000       0.447       0.557
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.3241      0.024     55.726      0.000       1.278       1.371
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.8961      0.022     41.577      0.000       0.854       0.938
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.5507      0.024     23.391      0.000       0.505       0.597
# log_insured_population                                    -0.0532      0.005    -10.934      0.000      -0.063      -0.044
# log_number_of_patents                                      0.0598      0.005     11.102      0.000       0.049       0.070
# log_enterprise_age                                        -0.0501      0.005    -11.112      0.000      -0.059      -0.041
# double_world_class                                        -0.0059      0.013     -0.463      0.644      -0.031       0.019
# log_patent_sq                                             -0.0412      0.002    -19.125      0.000      -0.045      -0.037
# ==============================================================================
# Omnibus:                     3606.662   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5081.029
# Skew:                          -0.609   Prob(JB):                         0.00
# Kurtosis:                       3.961   Cond. No.                         62.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.350
# Model:                                                       OLS   Adj. R-squared:                  0.349
# Method:                                            Least Squares   F-statistic:                     1088.
# Date:                                           Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   11:00:05   Log-Likelihood:                -61107.
# No. Observations:                                          50703   AIC:                         1.223e+05
# Df Residuals:                                              50680   BIC:                         1.225e+05
# Df Model:                                                     22
# Covariance Type:                                             HC1
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.4598      0.013    648.649      0.000       8.434       8.485
# industry_agriculture[T.True]                               0.0271      0.099      0.274      0.784      -0.167       0.221
# industry_other_services[T.True]                           -0.4974      0.098     -5.074      0.000      -0.690      -0.305
# industry_rnd_it[T.True]                                   -0.4114      0.009    -45.591      0.000      -0.429      -0.394
# industry_trade_construction_business[T.True]              -0.2906      0.015    -19.089      0.000      -0.320      -0.261
# industry_utilities[T.True]                                -0.2938      0.050     -5.933      0.000      -0.391      -0.197
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.5525      0.015     35.805      0.000       0.522       0.583
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          1.2948      0.035     37.449      0.000       1.227       1.363
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     1.0934      0.047     23.391      0.000       1.002       1.185
# C(city, Treatment(reference="NanJing"))[T.NanTong]         1.1338      0.020     57.373      0.000       1.095       1.173
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.5648      0.033     47.499      0.000       1.500       1.629
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6863      0.013     53.697      0.000       0.661       0.711
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1912      0.023     52.332      0.000       1.147       1.236
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.8693      0.013     66.885      0.000       0.844       0.895
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          1.3505      0.036     37.484      0.000       1.280       1.421
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.7680      0.021     83.758      0.000       1.727       1.809
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.9815      0.022     45.108      0.000       0.939       1.024
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.9758      0.023     42.811      0.000       0.931       1.020
# log_insured_population                                    -0.0584      0.005    -12.126      0.000      -0.068      -0.049
# log_number_of_patents                                      0.0693      0.005     13.069      0.000       0.059       0.080
# log_enterprise_age                                        -0.0551      0.004    -12.433      0.000      -0.064      -0.046
# double_world_class                                        -0.3594      0.012    -28.848      0.000      -0.384      -0.335
# log_patent_sq                                             -0.0360      0.002    -17.558      0.000      -0.040      -0.032
# ==============================================================================
# Omnibus:                     5097.698   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.011
# Skew:                          -0.744   Prob(JB):                         0.00
# Kurtosis:                       4.254   Cond. No.                         62.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
