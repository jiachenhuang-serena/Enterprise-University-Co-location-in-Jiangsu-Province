# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Statistical tests
from scipy.stats import skew, kurtosis, shapiro

# Coordinate transformation and distance calculation
from pyproj import Transformer
from scipy.spatial.distance import cdist
import math

from statsmodels.stats.diagnostic import het_breuschpagan

# %%
df = pd.read_excel("company-university-NJ-1.xlsx")

print("Initial data overview:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Initial data overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7093 entries, 0 to 7092
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   number_of_patents                          7093 non-null   int64
#  1   city                                       7093 non-null   object
#  2   county                                     7093 non-null   object
#  3   national_industry_category(GB standard)    7093 non-null   object
#  4   date                                       7093 non-null   object
#  5   insured_population                         7093 non-null   int64
#  6   x_utm                                      7093 non-null   float64
#  7   y_utm                                      7093 non-null   float64
#  8   nearest_university_distance_m              7093 non-null   float64
#  9   double_world_class                         7093 non-null   int64
#  10  Undergraduate University                   7093 non-null   object
#  11  distance_to_nearest_bachelor_university_m  7093 non-null   float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 665.1+ KB
#
# Missing values:
# number_of_patents                            0
# city                                         0
# county                                       0
# national_industry_category(GB standard)      0
# date                                         0
# insured_population                           0
# x_utm                                        0
# y_utm                                        0
# nearest_university_distance_m                0
# double_world_class                           0
# Undergraduate University                     0
# distance_to_nearest_bachelor_university_m    0
# dtype: int64

# %%
# Convert establishment date to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Calculate firm age in years
today = pd.Timestamp.today()
df['enterprise_age'] = (today - df['date']).dt.days / 365.25

# Display age range
print(f"Firm age computed: range {df['enterprise_age'].min():.1f} ~ {df['enterprise_age'].max():.1f} years")
# Out:
# Firm age computed: range 2.4 ~ 45.7 years

# %%
# Define the order of industry categories with 'Manufacturing' as the baseline (first)
industry_order = [
    'Manufacturing',  # Baseline category
    'Agriculture and Related Activities',
    'Other Services',
    'R&D and IT Services',
    'Trade, Construction, and Business Services',
    'Utilities and Infrastructure'
]

# Convert the industry column to a categorical type with specified order
df['national_industry_category(GB standard)'] = pd.Categorical(
    df['national_industry_category(GB standard)'],
    categories=industry_order,
    ordered=True
)

# Create dummy variables, dropping the first category ('Manufacturing') as the baseline
df = pd.get_dummies(df, columns=['national_industry_category(GB standard)'], drop_first=True)

# Rename dummy variable columns for clarity
df.rename(columns={
    'national_industry_category(GB standard)_Agriculture and Related Activities': 'industry_agriculture',
    'national_industry_category(GB standard)_Other Services': 'industry_other_services',
    'national_industry_category(GB standard)_R&D and IT Services': 'industry_rnd_it',
    'national_industry_category(GB standard)_Trade, Construction, and Business Services': 'industry_trade_construction_business',
    'national_industry_category(GB standard)_Utilities and Infrastructure': 'industry_utilities'
}, inplace=True)

# Define the list of dummy variable columns (excluding the baseline)
industry_cols = [
    'industry_agriculture',
    'industry_other_services',
    'industry_rnd_it',
    'industry_trade_construction_business',
    'industry_utilities'
]

print(f"Industry dummy variables created (baseline = 'Manufacturing'): {industry_cols}")
# Out:
# Industry dummy variables created (baseline = 'Manufacturing'): ['industry_agriculture', 'industry_other_services', 'industry_rnd_it', 'industry_trade_construction_business', 'industry_utilities']

# %%
# Descriptive statistics and correlation
num_vars = [
    'nearest_university_distance_m', 'distance_to_nearest_bachelor_university_m', 'insured_population',
    'number_of_patents', 'enterprise_age'
]

print("\nDescriptive statistics of numerical variables:")
print(df[num_vars].describe())

# Correlation matrix
corr_matrix = df[num_vars].corr()
print("\nCorrelation matrix:")
print(corr_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

corr_matrix.to_csv("correlation_matrix.csv")
# Out:
# Descriptive statistics of numerical variables:
#        nearest_university_distance_m  \
# count                    7093.000000
# mean                     3978.256973
# std                      4121.033196
# min                        14.241553
# 25%                      1320.944193
# 50%                      2431.491150
# 75%                      5295.176906
# max                     37080.322224
#
#        distance_to_nearest_bachelor_university_m  insured_population  \
# count                                7093.000000         7093.000000
# mean                                 4756.466013           81.493444
# std                                  4972.237820          290.527251
# min                                    20.146359            1.000000
# 25%                                  1585.303893            8.000000
# 50%                                  2634.424712           22.000000
# 75%                                  6619.399263           60.000000
# max                                 40660.832712         9838.000000
#
#        number_of_patents  enterprise_age
# count        7093.000000     7093.000000
# mean           64.317214       12.544778
# std           256.521400        7.014013
# min             1.000000        2.422998
# 25%            12.000000        7.077344
# 50%            28.000000       10.584531
# 75%            55.000000       16.739220
# max          9079.000000       45.741273
#
# Correlation matrix:
#                                            nearest_university_distance_m  \
# nearest_university_distance_m                                   1.000000
# distance_to_nearest_bachelor_university_m                       0.941927
# insured_population                                             -0.027336
# number_of_patents                                              -0.023675
# enterprise_age                                                  0.047498
#
#                                            distance_to_nearest_bachelor_university_m  \
# nearest_university_distance_m                                               0.941927
# distance_to_nearest_bachelor_university_m                                   1.000000
# insured_population                                                         -0.020165
# number_of_patents                                                          -0.024049
# enterprise_age                                                              0.054712
#
#                                            insured_population  \
# nearest_university_distance_m                       -0.027336
# distance_to_nearest_bachelor_university_m           -0.020165
# insured_population                                   1.000000
# number_of_patents                                    0.508157
# enterprise_age                                       0.252273
#
#                                            number_of_patents  enterprise_age
# nearest_university_distance_m                      -0.023675        0.047498
# distance_to_nearest_bachelor_university_m          -0.024049        0.054712
# insured_population                                  0.508157        0.252273
# number_of_patents                                   1.000000        0.195971
# enterprise_age                                      0.195971        1.000000

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['nearest_university_distance_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['nearest_university_distance_m'])
dist_kurt = kurtosis(df['nearest_university_distance_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['nearest_university_distance_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])
    y1_var = "log_nearest_university_distance_m"
else:
    y1_var = "nearest_university_distance_m"
# Out:
# Skewness of `distance`: 2.54
# Kurtosis of `distance`: 9.76
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 7093.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['distance_to_nearest_bachelor_university_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['distance_to_nearest_bachelor_university_m'])
dist_kurt = kurtosis(df['distance_to_nearest_bachelor_university_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['distance_to_nearest_bachelor_university_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])
    y2_var = "log_distance_to_nearest_bachelor_university_m"
else:
    y2_var = "distance_to_nearest_bachelor_university_m"
# Out:
# Skewness of `distance`: 2.19
# Kurtosis of `distance`: 6.55
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 7093.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Define variable list
variables = ['insured_population', 'number_of_patents', 'enterprise_age']

# Plot distributions
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Original distribution
    plt.subplot(3, 2, 2*i+1)
    sns.histplot(df[var].dropna(), bins=30, kde=True)
    plt.title(f"Distribution of {var}")

    # log1p-transformed distribution
    plt.subplot(3, 2, 2*i+2)
    sns.histplot(np.log1p(df[var].dropna()), bins=30, kde=True)
    plt.title(f"Distribution of log1p({var})")

plt.tight_layout()
plt.show()

# %%
# Apply log(1 + x) transformation to reduce skewness and handle zeros safely
df['log_number_of_patents'] = np.log1p(df['number_of_patents'])
df['log_insured_population'] = np.log1p(df['insured_population'])
df['log_enterprise_age'] = np.log1p(df['enterprise_age'])

# %%
# Standardize numerical independent variables
std_vars = [
    'log_insured_population', 'log_number_of_patents', 'log_enterprise_age'
]
scaler = StandardScaler()
df[std_vars] = scaler.fit_transform(df[std_vars])

# %%
# Define y and prepare X for VIF

# Use log-transformed distance as the dependent variable
df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])  # log(1 + x) avoids log(0)
y1 = df['nearest_university_distance_m']  #  this is the new target variable
# Use log-transformed distance as the dependent variable
df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])  # log(1 + x) avoids log(0)
y2 = df['distance_to_nearest_bachelor_university_m']  #  this is the new target variable

# Combine standardized numeric variables and industry dummies
X_vars = std_vars + industry_cols + ['double_world_class']
X = df[X_vars]

# %%
X
# Out:
#       log_insured_population  log_number_of_patents  log_enterprise_age  \
# 0                   2.695304               0.583720            0.544699
# 1                   2.547935               1.146536            1.241219
# 2                  -0.678233               0.126947           -1.088444
# 3                   1.425177               0.684037           -1.390372
# 4                   1.060141               1.724665            1.109502
# ...                      ...                    ...                 ...
# 7088               -0.678233              -1.795108           -0.261586
# 7089               -1.345045              -1.795108           -0.137245
# 7090               -1.049976              -1.795108           -0.535645
# 7091               -1.345045              -1.224635           -1.162412
# 7092               -1.849469              -1.558340           -1.332455
#
#       industry_agriculture  industry_other_services  industry_rnd_it  \
# 0                    False                    False            False
# 1                    False                    False             True
# 2                    False                    False            False
# 3                    False                    False             True
# 4                    False                    False             True
# ...                    ...                      ...              ...
# 7088                 False                    False             True
# 7089                 False                    False             True
# 7090                 False                    False             True
# 7091                 False                    False             True
# 7092                 False                    False             True
#
#       industry_trade_construction_business  industry_utilities  \
# 0                                     True               False
# 1                                    False               False
# 2                                    False               False
# 3                                    False               False
# 4                                    False               False
# ...                                    ...                 ...
# 7088                                 False               False
# 7089                                 False               False
# 7090                                 False               False
# 7091                                 False               False
# 7092                                 False               False
#
#       double_world_class
# 0                      1
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 7088                   0
# 7089                   0
# 7090                   0
# 7091                   0
# 7092                   0
#
# [7093 rows x 9 columns]

# %%
print("\n X column data types:")
print(X.dtypes)
# Out:
#  X column data types:
# log_insured_population                  float64
# log_number_of_patents                   float64
# log_enterprise_age                      float64
# industry_agriculture                       bool
# industry_other_services                    bool
# industry_rnd_it                            bool
# industry_trade_construction_business       bool
# industry_utilities                         bool
# double_world_class                        int64
# dtype: object

# %%
# Construct the squared term of log-transformed number of patents
df['log_patent_sq'] = df['log_number_of_patents'] ** 2

# %%
X_vars = std_vars + industry_cols + ['double_world_class'] + ['log_patent_sq']
X = df[X_vars]

# %%
X = df[X_vars].copy()
X = X.astype(float)

# %%
# VIF calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("\n Variance Inflation Factors (VIF):")
print(vif_df)
# Out:
#  Variance Inflation Factors (VIF):
#                                 feature       VIF
# 0                log_insured_population  1.732104
# 1                 log_number_of_patents  1.697610
# 2                    log_enterprise_age  1.375819
# 3                  industry_agriculture  1.001807
# 4               industry_other_services  1.007739
# 5                       industry_rnd_it  1.692726
# 6  industry_trade_construction_business  1.104011
# 7                    industry_utilities  1.011965
# 8                    double_world_class  1.368119
# 9                         log_patent_sq  1.424411

# %%
# Combine all independent variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define regression formula with city fixed effects
formula1 = 'log_nearest_university_distance_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="JiangNing"))'

# Fit the OLS regression model
model1 = smf.ols(formula=formula1, data=df).fit()
print(model1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.330
# Model:                                           OLS   Adj. R-squared:                  0.328
# Method:                                Least Squares   F-statistic:                     174.0
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:16:15   Log-Likelihood:                -8495.4
# No. Observations:                               7093   AIC:                         1.703e+04
# Df Residuals:                                   7072   BIC:                         1.718e+04
# Df Model:                                         20
# Covariance Type:                           nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   8.1187      0.029    283.061      0.000       8.062       8.175
# industry_agriculture[T.True]                               -0.0177      0.233     -0.076      0.940      -0.474       0.439
# industry_other_services[T.True]                            -0.3825      0.146     -2.613      0.009      -0.670      -0.096
# industry_rnd_it[T.True]                                    -0.3582      0.027    -13.476      0.000      -0.410      -0.306
# industry_trade_construction_business[T.True]               -0.1925      0.035     -5.494      0.000      -0.261      -0.124
# industry_utilities[T.True]                                 -0.2403      0.081     -2.966      0.003      -0.399      -0.081
# C(county, Treatment(reference="JiangNing"))[T.GaoChun]      0.7427      0.050     14.760      0.000       0.644       0.841
# C(county, Treatment(reference="JiangNing"))[T.GuLou]       -1.0946      0.045    -24.065      0.000      -1.184      -1.005
# C(county, Treatment(reference="JiangNing"))[T.JianYe]      -0.1912      0.045     -4.215      0.000      -0.280      -0.102
# C(county, Treatment(reference="JiangNing"))[T.LiShui]       0.4034      0.041      9.783      0.000       0.323       0.484
# C(county, Treatment(reference="JiangNing"))[T.LiuHe]        0.9912      0.039     25.289      0.000       0.914       1.068
# C(county, Treatment(reference="JiangNing"))[T.PuKou]       -0.1141      0.032     -3.527      0.000      -0.178      -0.051
# C(county, Treatment(reference="JiangNing"))[T.QiXia]       -0.0006      0.038     -0.016      0.987      -0.074       0.073
# C(county, Treatment(reference="JiangNing"))[T.QinHuai]     -0.6961      0.046    -15.067      0.000      -0.787      -0.606
# C(county, Treatment(reference="JiangNing"))[T.XuanWu]      -0.6916      0.051    -13.670      0.000      -0.791      -0.592
# C(county, Treatment(reference="JiangNing"))[T.YuHuaTai]    -0.1658      0.039     -4.300      0.000      -0.241      -0.090
# log_insured_population                                     -0.0392      0.013     -3.099      0.002      -0.064      -0.014
# log_number_of_patents                                       0.0356      0.013      2.770      0.006       0.010       0.061
# log_enterprise_age                                         -0.0498      0.012     -4.291      0.000      -0.072      -0.027
# double_world_class                                          0.0885      0.023      3.783      0.000       0.043       0.134
# log_patent_sq                                              -0.0383      0.006     -6.148      0.000      -0.050      -0.026
# ==============================================================================
# Omnibus:                      562.987   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              985.001
# Skew:                          -0.579   Prob(JB):                    1.29e-214
# Kurtosis:                       4.412   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Combine all explanatory variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define the regression formula
formula2 = 'log_distance_to_nearest_bachelor_university_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="JiangNing"))'

# Fit the OLS regression model
model2 = smf.ols(formula=formula2, data=df).fit()
print(model2.summary())
# Out:
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.412
# Model:                                                       OLS   Adj. R-squared:                  0.410
# Method:                                            Least Squares   F-statistic:                     247.7
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:16:15   Log-Likelihood:                -7974.8
# No. Observations:                                           7093   AIC:                         1.599e+04
# Df Residuals:                                               7072   BIC:                         1.614e+04
# Df Model:                                                     20
# Covariance Type:                                       nonrobust
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   8.2625      0.027    310.015      0.000       8.210       8.315
# industry_agriculture[T.True]                               -0.0751      0.216     -0.347      0.728      -0.499       0.349
# industry_other_services[T.True]                            -0.3506      0.136     -2.577      0.010      -0.617      -0.084
# industry_rnd_it[T.True]                                    -0.3182      0.025    -12.882      0.000      -0.367      -0.270
# industry_trade_construction_business[T.True]               -0.1495      0.033     -4.591      0.000      -0.213      -0.086
# industry_utilities[T.True]                                 -0.2398      0.075     -3.184      0.001      -0.387      -0.092
# C(county, Treatment(reference="JiangNing"))[T.GaoChun]      0.6033      0.047     12.902      0.000       0.512       0.695
# C(county, Treatment(reference="JiangNing"))[T.GuLou]       -0.9866      0.042    -23.342      0.000      -1.069      -0.904
# C(county, Treatment(reference="JiangNing"))[T.JianYe]      -0.2232      0.042     -5.295      0.000      -0.306      -0.141
# C(county, Treatment(reference="JiangNing"))[T.LiShui]       0.7454      0.038     19.453      0.000       0.670       0.821
# C(county, Treatment(reference="JiangNing"))[T.LiuHe]        1.2524      0.036     34.388      0.000       1.181       1.324
# C(county, Treatment(reference="JiangNing"))[T.PuKou]       -0.0799      0.030     -2.659      0.008      -0.139      -0.021
# C(county, Treatment(reference="JiangNing"))[T.QiXia]       -0.0682      0.035     -1.950      0.051      -0.137       0.000
# C(county, Treatment(reference="JiangNing"))[T.QinHuai]     -0.4303      0.043    -10.021      0.000      -0.514      -0.346
# C(county, Treatment(reference="JiangNing"))[T.XuanWu]      -0.6789      0.047    -14.441      0.000      -0.771      -0.587
# C(county, Treatment(reference="JiangNing"))[T.YuHuaTai]    -0.2517      0.036     -7.025      0.000      -0.322      -0.181
# log_insured_population                                     -0.0418      0.012     -3.554      0.000      -0.065      -0.019
# log_number_of_patents                                       0.0394      0.012      3.298      0.001       0.016       0.063
# log_enterprise_age                                         -0.0406      0.011     -3.769      0.000      -0.062      -0.019
# double_world_class                                         -0.1304      0.022     -6.000      0.000      -0.173      -0.088
# log_patent_sq                                              -0.0324      0.006     -5.600      0.000      -0.044      -0.021
# ==============================================================================
# Omnibus:                      361.398   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              596.688
# Skew:                          -0.423   Prob(JB):                    2.70e-130
# Kurtosis:                       4.142   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create side-by-side residual plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Residual plot for distance to any university
axs[0].scatter(model1.fittedvalues, model1.resid, alpha=0.5)
axs[0].axhline(0, color='red')
axs[0].set_title("Residual Plot - Any University")
axs[0].set_xlabel("Fitted Values")
axs[0].set_ylabel("Residuals")

# Residual plot for distance to nearest bachelor-level university
axs[1].scatter(model2.fittedvalues, model2.resid, alpha=0.5)
axs[1].axhline(0, color='red')
axs[1].set_title("Residual Plot - Bachelor-level University")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Residuals")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Extract residuals and design matrix from the model
resid = model1.resid
exog = model1.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 151.7337
# p-value: 0.0000
# F-statistic: 7.7296
# F p-value: 0.0000

# %%
# Extract residuals and design matrix from the model
resid = model2.resid
exog = model2.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 158.7383
# p-value: 0.0000
# F-statistic: 8.0946
# F p-value: 0.0000

# %%
model1_robust = model1.get_robustcov_results(cov_type='HC1')
print(model1_robust.summary())

model2_robust = model2.get_robustcov_results(cov_type='HC1')
print(model2_robust.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.330
# Model:                                           OLS   Adj. R-squared:                  0.328
# Method:                                Least Squares   F-statistic:                     159.6
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:16:31   Log-Likelihood:                -8495.4
# No. Observations:                               7093   AIC:                         1.703e+04
# Df Residuals:                                   7072   BIC:                         1.718e+04
# Df Model:                                         20
# Covariance Type:                                 HC1
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   8.1187      0.031    265.631      0.000       8.059       8.179
# industry_agriculture[T.True]                               -0.0177      0.289     -0.061      0.951      -0.585       0.550
# industry_other_services[T.True]                            -0.3825      0.119     -3.226      0.001      -0.615      -0.150
# industry_rnd_it[T.True]                                    -0.3582      0.027    -13.207      0.000      -0.411      -0.305
# industry_trade_construction_business[T.True]               -0.1925      0.037     -5.199      0.000      -0.265      -0.120
# industry_utilities[T.True]                                 -0.2403      0.091     -2.646      0.008      -0.418      -0.062
# C(county, Treatment(reference="JiangNing"))[T.GaoChun]      0.7427      0.047     15.841      0.000       0.651       0.835
# C(county, Treatment(reference="JiangNing"))[T.GuLou]       -1.0946      0.053    -20.790      0.000      -1.198      -0.991
# C(county, Treatment(reference="JiangNing"))[T.JianYe]      -0.1912      0.039     -4.938      0.000      -0.267      -0.115
# C(county, Treatment(reference="JiangNing"))[T.LiShui]       0.4034      0.043      9.320      0.000       0.319       0.488
# C(county, Treatment(reference="JiangNing"))[T.LiuHe]        0.9912      0.047     21.278      0.000       0.900       1.082
# C(county, Treatment(reference="JiangNing"))[T.PuKou]       -0.1141      0.031     -3.714      0.000      -0.174      -0.054
# C(county, Treatment(reference="JiangNing"))[T.QiXia]       -0.0006      0.037     -0.017      0.987      -0.073       0.072
# C(county, Treatment(reference="JiangNing"))[T.QinHuai]     -0.6961      0.049    -14.165      0.000      -0.792      -0.600
# C(county, Treatment(reference="JiangNing"))[T.XuanWu]      -0.6916      0.055    -12.500      0.000      -0.800      -0.583
# C(county, Treatment(reference="JiangNing"))[T.YuHuaTai]    -0.1658      0.040     -4.145      0.000      -0.244      -0.087
# log_insured_population                                     -0.0392      0.012     -3.187      0.001      -0.063      -0.015
# log_number_of_patents                                       0.0356      0.012      2.870      0.004       0.011       0.060
# log_enterprise_age                                         -0.0498      0.012     -4.316      0.000      -0.072      -0.027
# double_world_class                                          0.0885      0.026      3.421      0.001       0.038       0.139
# log_patent_sq                                              -0.0383      0.006     -6.265      0.000      -0.050      -0.026
# ==============================================================================
# Omnibus:                      562.987   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              985.001
# Skew:                          -0.579   Prob(JB):                    1.29e-214
# Kurtosis:                       4.412   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.412
# Model:                                                       OLS   Adj. R-squared:                  0.410
# Method:                                            Least Squares   F-statistic:                     254.2
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:16:31   Log-Likelihood:                -7974.8
# No. Observations:                                           7093   AIC:                         1.599e+04
# Df Residuals:                                               7072   BIC:                         1.614e+04
# Df Model:                                                     20
# Covariance Type:                                             HC1
# ===========================================================================================================================
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# Intercept                                                   8.2625      0.029    289.016      0.000       8.206       8.319
# industry_agriculture[T.True]                               -0.0751      0.292     -0.257      0.797      -0.647       0.497
# industry_other_services[T.True]                            -0.3506      0.109     -3.223      0.001      -0.564      -0.137
# industry_rnd_it[T.True]                                    -0.3182      0.025    -12.626      0.000      -0.368      -0.269
# industry_trade_construction_business[T.True]               -0.1495      0.034     -4.383      0.000      -0.216      -0.083
# industry_utilities[T.True]                                 -0.2398      0.092     -2.606      0.009      -0.420      -0.059
# C(county, Treatment(reference="JiangNing"))[T.GaoChun]      0.6033      0.043     14.025      0.000       0.519       0.688
# C(county, Treatment(reference="JiangNing"))[T.GuLou]       -0.9866      0.049    -20.322      0.000      -1.082      -0.891
# C(county, Treatment(reference="JiangNing"))[T.JianYe]      -0.2232      0.035     -6.346      0.000      -0.292      -0.154
# C(county, Treatment(reference="JiangNing"))[T.LiShui]       0.7454      0.041     18.278      0.000       0.665       0.825
# C(county, Treatment(reference="JiangNing"))[T.LiuHe]        1.2524      0.038     33.078      0.000       1.178       1.327
# C(county, Treatment(reference="JiangNing"))[T.PuKou]       -0.0799      0.031     -2.555      0.011      -0.141      -0.019
# C(county, Treatment(reference="JiangNing"))[T.QiXia]       -0.0682      0.034     -2.018      0.044      -0.134      -0.002
# C(county, Treatment(reference="JiangNing"))[T.QinHuai]     -0.4303      0.040    -10.629      0.000      -0.510      -0.351
# C(county, Treatment(reference="JiangNing"))[T.XuanWu]      -0.6789      0.052    -13.071      0.000      -0.781      -0.577
# C(county, Treatment(reference="JiangNing"))[T.YuHuaTai]    -0.2517      0.040     -6.280      0.000      -0.330      -0.173
# log_insured_population                                     -0.0418      0.011     -3.655      0.000      -0.064      -0.019
# log_number_of_patents                                       0.0394      0.012      3.410      0.001       0.017       0.062
# log_enterprise_age                                         -0.0406      0.011     -3.738      0.000      -0.062      -0.019
# double_world_class                                         -0.1304      0.026     -5.103      0.000      -0.180      -0.080
# log_patent_sq                                              -0.0324      0.005     -5.968      0.000      -0.043      -0.022
# ==============================================================================
# Omnibus:                      361.398   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              596.688
# Skew:                          -0.423   Prob(JB):                    2.70e-130
# Kurtosis:                       4.142   Cond. No.                         50.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
