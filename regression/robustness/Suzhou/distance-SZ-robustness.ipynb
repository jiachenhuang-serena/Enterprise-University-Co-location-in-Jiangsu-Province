# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Statistical tests
from scipy.stats import skew, kurtosis, shapiro

# Coordinate transformation and distance calculation
from pyproj import Transformer
from scipy.spatial.distance import cdist
import math

from statsmodels.stats.diagnostic import het_breuschpagan

# %%
df = pd.read_excel("company-university-SZ-1.xlsx")

print("Initial data overview:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Initial data overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14401 entries, 0 to 14400
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   number_of_patents                          14401 non-null  int64
#  1   city                                       14401 non-null  object
#  2   county                                     14401 non-null  object
#  3   national_industry_category(GB standard)    14401 non-null  object
#  4   date                                       14401 non-null  object
#  5   insured_population                         14401 non-null  int64
#  6   x_utm                                      14401 non-null  float64
#  7   y_utm                                      14401 non-null  float64
#  8   nearest_university_distance_m              14401 non-null  float64
#  9   double_world_class                         14401 non-null  int64
#  10  Undergraduate University                   14401 non-null  object
#  11  distance_to_nearest_bachelor_university_m  14401 non-null  float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.3+ MB
#
# Missing values:
# number_of_patents                            0
# city                                         0
# county                                       0
# national_industry_category(GB standard)      0
# date                                         0
# insured_population                           0
# x_utm                                        0
# y_utm                                        0
# nearest_university_distance_m                0
# double_world_class                           0
# Undergraduate University                     0
# distance_to_nearest_bachelor_university_m    0
# dtype: int64

# %%
# Convert establishment date to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Calculate firm age in years
today = pd.Timestamp.today()
df['enterprise_age'] = (today - df['date']).dt.days / 365.25

# Display age range
print(f"Firm age computed: range {df['enterprise_age'].min():.1f} ~ {df['enterprise_age'].max():.1f} years")
# Out:
# Firm age computed: range 2.3 ~ 45.6 years

# %%
# Define the order of industry categories with 'Manufacturing' as the baseline (first)
industry_order = [
    'Manufacturing',  # Baseline category
    'Agriculture and Related Activities',
    'Other Services',
    'R&D and IT Services',
    'Trade, Construction, and Business Services',
    'Utilities and Infrastructure'
]

# Convert the industry column to a categorical type with specified order
df['national_industry_category(GB standard)'] = pd.Categorical(
    df['national_industry_category(GB standard)'],
    categories=industry_order,
    ordered=True
)

# Create dummy variables, dropping the first category ('Manufacturing') as the baseline
df = pd.get_dummies(df, columns=['national_industry_category(GB standard)'], drop_first=True)

# Rename dummy variable columns for clarity
df.rename(columns={
    'national_industry_category(GB standard)_Agriculture and Related Activities': 'industry_agriculture',
    'national_industry_category(GB standard)_Other Services': 'industry_other_services',
    'national_industry_category(GB standard)_R&D and IT Services': 'industry_rnd_it',
    'national_industry_category(GB standard)_Trade, Construction, and Business Services': 'industry_trade_construction_business',
    'national_industry_category(GB standard)_Utilities and Infrastructure': 'industry_utilities'
}, inplace=True)

# Define the list of dummy variable columns (excluding the baseline)
industry_cols = [
    'industry_agriculture',
    'industry_other_services',
    'industry_rnd_it',
    'industry_trade_construction_business',
    'industry_utilities'
]

print(f"Industry dummy variables created (baseline = 'Manufacturing'): {industry_cols}")
# Out:
# Industry dummy variables created (baseline = 'Manufacturing'): ['industry_agriculture', 'industry_other_services', 'industry_rnd_it', 'industry_trade_construction_business', 'industry_utilities']

# %%
# Descriptive statistics and correlation
num_vars = [
    'nearest_university_distance_m', 'distance_to_nearest_bachelor_university_m', 'insured_population',
    'number_of_patents', 'enterprise_age'
]

print("\nDescriptive statistics of numerical variables:")
print(df[num_vars].describe())

# Correlation matrix
corr_matrix = df[num_vars].corr()
print("\nCorrelation matrix:")
print(corr_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

corr_matrix.to_csv("correlation_matrix.csv")
# Out:
# Descriptive statistics of numerical variables:
#        nearest_university_distance_m  \
# count                   14401.000000
# mean                     7103.871260
# std                      4208.630166
# min                        44.301665
# 25%                      3667.696346
# 50%                      6656.002654
# 75%                      9954.651460
# max                     20529.818040
#
#        distance_to_nearest_bachelor_university_m  insured_population  \
# count                               14401.000000        14401.000000
# mean                                 9299.288532          111.340046
# std                                  5774.659272          708.774212
# min                                    44.301665            1.000000
# 25%                                  4833.064812           13.000000
# 50%                                  8541.640980           30.000000
# 75%                                 12293.523127           78.000000
# max                                 35215.950403        54532.000000
#
#        number_of_patents  enterprise_age
# count       14401.000000    14401.000000
# mean           77.589542       12.953297
# std           397.262951        6.859909
# min             1.000000        2.305270
# 25%            22.000000        7.679671
# 50%            38.000000       11.356605
# 75%            68.000000       17.237509
# max         36808.000000       45.585216
#
# Correlation matrix:
#                                            nearest_university_distance_m  \
# nearest_university_distance_m                                   1.000000
# distance_to_nearest_bachelor_university_m                       0.776500
# insured_population                                              0.006160
# number_of_patents                                              -0.009333
# enterprise_age                                                  0.082635
#
#                                            distance_to_nearest_bachelor_university_m  \
# nearest_university_distance_m                                               0.776500
# distance_to_nearest_bachelor_university_m                                   1.000000
# insured_population                                                          0.003311
# number_of_patents                                                          -0.007551
# enterprise_age                                                              0.064144
#
#                                            insured_population  \
# nearest_university_distance_m                        0.006160
# distance_to_nearest_bachelor_university_m            0.003311
# insured_population                                   1.000000
# number_of_patents                                    0.270218
# enterprise_age                                       0.118465
#
#                                            number_of_patents  enterprise_age
# nearest_university_distance_m                      -0.009333        0.082635
# distance_to_nearest_bachelor_university_m          -0.007551        0.064144
# insured_population                                  0.270218        0.118465
# number_of_patents                                   1.000000        0.103857
# enterprise_age                                      0.103857        1.000000

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['nearest_university_distance_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['nearest_university_distance_m'])
dist_kurt = kurtosis(df['nearest_university_distance_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['nearest_university_distance_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])
    y1_var = "log_nearest_university_distance_m"
else:
    y1_var = "nearest_university_distance_m"
# Out:
# Skewness of `distance`: 0.57
# Kurtosis of `distance`: -0.32
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 14401.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['distance_to_nearest_bachelor_university_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['distance_to_nearest_bachelor_university_m'])
dist_kurt = kurtosis(df['distance_to_nearest_bachelor_university_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['distance_to_nearest_bachelor_university_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])
    y2_var = "log_distance_to_nearest_bachelor_university_m"
else:
    y2_var = "distance_to_nearest_bachelor_university_m"
# Out:
# Skewness of `distance`: 1.03
# Kurtosis of `distance`: 1.25
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 14401.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Define variable list
variables = ['insured_population', 'number_of_patents', 'enterprise_age']

# Plot distributions
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Original distribution
    plt.subplot(3, 2, 2*i+1)
    sns.histplot(df[var].dropna(), bins=30, kde=True)
    plt.title(f"Distribution of {var}")

    # log1p-transformed distribution
    plt.subplot(3, 2, 2*i+2)
    sns.histplot(np.log1p(df[var].dropna()), bins=30, kde=True)
    plt.title(f"Distribution of log1p({var})")

plt.tight_layout()
plt.show()

# %%
# Apply log(1 + x) transformation to reduce skewness and handle zeros safely
df['log_number_of_patents'] = np.log1p(df['number_of_patents'])
df['log_insured_population'] = np.log1p(df['insured_population'])
df['log_enterprise_age'] = np.log1p(df['enterprise_age'])

# %%
# Standardize numerical independent variables
std_vars = [
    'log_insured_population', 'log_number_of_patents', 'log_enterprise_age'
]
scaler = StandardScaler()
df[std_vars] = scaler.fit_transform(df[std_vars])

# %%
# Define y and prepare X for VIF

# Use log-transformed distance as the dependent variable
df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])  # log(1 + x) avoids log(0)
y1 = df['nearest_university_distance_m']  #  this is the new target variable
# Use log-transformed distance as the dependent variable
df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])  # log(1 + x) avoids log(0)
y2 = df['distance_to_nearest_bachelor_university_m']  #  this is the new target variable

# Combine standardized numeric variables and industry dummies
X_vars = std_vars + industry_cols + ['double_world_class']
X = df[X_vars]

# %%
X
# Out:
#        log_insured_population  log_number_of_patents  log_enterprise_age  \
# 0                    1.946749               2.289373            0.011073
# 1                    2.441067               2.209423            2.311468
# 2                    2.828581               3.899708            1.971038
# 3                    1.871679               3.059021            2.284287
# 4                    2.413695               2.042219            1.894499
# ...                       ...                    ...                 ...
# 14396                0.183034              -0.691259           -0.291696
# 14397                0.263766              -0.394048            0.651178
# 14398               -1.448200               1.642343            0.576820
# 14399               -0.271615              -1.359305           -0.296379
# 14400               -2.135489              -3.120522           -1.108316
#
#        industry_agriculture  industry_other_services  industry_rnd_it  \
# 0                     False                    False             True
# 1                     False                    False             True
# 2                     False                    False            False
# 3                     False                    False            False
# 4                     False                    False             True
# ...                     ...                      ...              ...
# 14396                 False                    False             True
# 14397                 False                    False            False
# 14398                 False                    False             True
# 14399                 False                    False            False
# 14400                 False                    False             True
#
#        industry_trade_construction_business  industry_utilities  \
# 0                                     False               False
# 1                                     False               False
# 2                                     False               False
# 3                                     False               False
# 4                                     False               False
# ...                                     ...                 ...
# 14396                                 False               False
# 14397                                 False               False
# 14398                                 False               False
# 14399                                 False               False
# 14400                                 False               False
#
#        double_world_class
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 14396                   0
# 14397                   0
# 14398                   0
# 14399                   0
# 14400                   0
#
# [14401 rows x 9 columns]

# %%
print("\n X column data types:")
print(X.dtypes)
# Out:
#  X column data types:
# log_insured_population                  float64
# log_number_of_patents                   float64
# log_enterprise_age                      float64
# industry_agriculture                       bool
# industry_other_services                    bool
# industry_rnd_it                            bool
# industry_trade_construction_business       bool
# industry_utilities                         bool
# double_world_class                        int64
# dtype: object

# %%
# Construct the squared term of log-transformed number of patents
df['log_patent_sq'] = df['log_number_of_patents'] ** 2

# %%
X_vars = std_vars + industry_cols + ['double_world_class'] + ['log_patent_sq']
X = df[X_vars]

# %%
X = df[X_vars].copy()
X = X.astype(float)

# %%
# VIF calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("\n Variance Inflation Factors (VIF):")
print(vif_df)
# Out:
#  Variance Inflation Factors (VIF):
#                                 feature       VIF
# 0                log_insured_population  1.757365
# 1                 log_number_of_patents  1.804332
# 2                    log_enterprise_age  1.415628
# 3                  industry_agriculture  1.000918
# 4               industry_other_services  1.003911
# 5                       industry_rnd_it  1.355610
# 6  industry_trade_construction_business  1.037319
# 7                    industry_utilities  1.003516
# 8                    double_world_class  1.076435
# 9                         log_patent_sq  1.236636

# %%
# Combine all independent variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define regression formula with city fixed effects
formula1 = 'log_nearest_university_distance_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="KunShan"))'

# Fit the OLS regression model
model1 = smf.ols(formula=formula1, data=df).fit()
print(model1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.210
# Model:                                           OLS   Adj. R-squared:                  0.209
# Method:                                Least Squares   F-statistic:                     201.8
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:23:32   Log-Likelihood:                -14746.
# No. Observations:                              14401   AIC:                         2.953e+04
# Df Residuals:                                  14381   BIC:                         2.968e+04
# Df Model:                                         19
# Covariance Type:                           nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.0010      0.013    673.531      0.000       8.975       9.027
# industry_agriculture[T.True]                                           -0.2886      0.255     -1.131      0.258      -0.789       0.211
# industry_other_services[T.True]                                        -0.4232      0.164     -2.580      0.010      -0.745      -0.102
# industry_rnd_it[T.True]                                                -0.2674      0.014    -18.853      0.000      -0.295      -0.240
# industry_trade_construction_business[T.True]                           -0.1424      0.022     -6.598      0.000      -0.185      -0.100
# industry_utilities[T.True]                                             -0.1133      0.069     -1.650      0.099      -0.248       0.021
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.1377      0.022      6.130      0.000       0.094       0.182
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.2146      0.061    -19.909      0.000      -1.334      -1.095
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5464      0.023    -23.605      0.000      -0.592      -0.501
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.5498      0.022    -25.494      0.000      -0.592      -0.508
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0808      0.024     -3.402      0.001      -0.127      -0.034
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                   -0.1518      0.022     -6.818      0.000      -0.195      -0.108
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.5491      0.020    -26.814      0.000      -0.589      -0.509
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.1564      0.022     -7.160      0.000      -0.199      -0.114
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]               0.0818      0.024      3.447      0.001       0.035       0.128
# log_insured_population                                                 -0.0025      0.008     -0.334      0.739      -0.017       0.012
# log_number_of_patents                                                   0.0348      0.008      4.580      0.000       0.020       0.050
# log_enterprise_age                                                     -0.0011      0.007     -0.160      0.873      -0.015       0.012
# double_world_class                                                     -0.1157      0.020     -5.666      0.000      -0.156      -0.076
# log_patent_sq                                                          -0.0289      0.003     -9.946      0.000      -0.035      -0.023
# ==============================================================================
# Omnibus:                     2414.696   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4386.459
# Skew:                          -1.065   Prob(JB):                         0.00
# Kurtosis:                       4.664   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Combine all explanatory variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define the regression formula
formula2 = 'log_distance_to_nearest_bachelor_university_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="KunShan"))'

# Fit the OLS regression model
model2 = smf.ols(formula=formula2, data=df).fit()
print(model2.summary())
# Out:
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.272
# Model:                                                       OLS   Adj. R-squared:                  0.271
# Method:                                            Least Squares   F-statistic:                     283.1
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:23:56   Log-Likelihood:                -13873.
# No. Observations:                                          14401   AIC:                         2.779e+04
# Df Residuals:                                              14381   BIC:                         2.794e+04
# Df Model:                                                     19
# Covariance Type:                                       nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.2518      0.013    735.574      0.000       9.227       9.276
# industry_agriculture[T.True]                                            0.0007      0.240      0.003      0.998      -0.470       0.471
# industry_other_services[T.True]                                        -0.0924      0.154     -0.599      0.549      -0.395       0.210
# industry_rnd_it[T.True]                                                -0.2170      0.013    -16.250      0.000      -0.243      -0.191
# industry_trade_construction_business[T.True]                           -0.1136      0.020     -5.590      0.000      -0.153      -0.074
# industry_utilities[T.True]                                             -0.1004      0.065     -1.554      0.120      -0.227       0.026
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.0479      0.021      2.267      0.023       0.006       0.089
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.2002      0.057    -20.904      0.000      -1.313      -1.088
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5852      0.022    -26.862      0.000      -0.628      -0.542
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.6189      0.020    -30.492      0.000      -0.659      -0.579
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0715      0.022     -3.197      0.001      -0.115      -0.028
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                    0.1746      0.021      8.332      0.000       0.134       0.216
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.4287      0.019    -22.239      0.000      -0.466      -0.391
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.0002      0.021     -0.011      0.992      -0.041       0.040
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]              -0.0764      0.022     -3.423      0.001      -0.120      -0.033
# log_insured_population                                                 -0.0021      0.007     -0.291      0.771      -0.016       0.012
# log_number_of_patents                                                   0.0268      0.007      3.743      0.000       0.013       0.041
# log_enterprise_age                                                     -0.0001      0.006     -0.022      0.982      -0.013       0.013
# double_world_class                                                     -0.4800      0.019    -24.964      0.000      -0.518      -0.442
# log_patent_sq                                                          -0.0230      0.003     -8.417      0.000      -0.028      -0.018
# ==============================================================================
# Omnibus:                     2520.296   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5155.506
# Skew:                          -1.050   Prob(JB):                         0.00
# Kurtosis:                       5.044   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create side-by-side residual plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Residual plot for distance to any university
axs[0].scatter(model1.fittedvalues, model1.resid, alpha=0.5)
axs[0].axhline(0, color='red')
axs[0].set_title("Residual Plot - Any University")
axs[0].set_xlabel("Fitted Values")
axs[0].set_ylabel("Residuals")

# Residual plot for distance to nearest bachelor-level university
axs[1].scatter(model2.fittedvalues, model2.resid, alpha=0.5)
axs[1].axhline(0, color='red')
axs[1].set_title("Residual Plot - Bachelor-level University")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Residuals")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Extract residuals and design matrix from the model
resid = model1.resid
exog = model1.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 773.9132
# p-value: 0.0000
# F-statistic: 42.9858
# F p-value: 0.0000

# %%
# Extract residuals and design matrix from the model
resid = model2.resid
exog = model2.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 669.2429
# p-value: 0.0000
# F-statistic: 36.8887
# F p-value: 0.0000

# %%
model1_robust = model1.get_robustcov_results(cov_type='HC1')
print(model1_robust.summary())

model2_robust = model2.get_robustcov_results(cov_type='HC1')
print(model2_robust.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.210
# Model:                                           OLS   Adj. R-squared:                  0.209
# Method:                                Least Squares   F-statistic:                     189.9
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:23:59   Log-Likelihood:                -14746.
# No. Observations:                              14401   AIC:                         2.953e+04
# Df Residuals:                                  14381   BIC:                         2.968e+04
# Df Model:                                         19
# Covariance Type:                                 HC1
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.0010      0.011    805.850      0.000       8.979       9.023
# industry_agriculture[T.True]                                           -0.2886      0.419     -0.688      0.491      -1.110       0.533
# industry_other_services[T.True]                                        -0.4232      0.246     -1.719      0.086      -0.906       0.059
# industry_rnd_it[T.True]                                                -0.2674      0.015    -18.274      0.000      -0.296      -0.239
# industry_trade_construction_business[T.True]                           -0.1424      0.021     -6.891      0.000      -0.183      -0.102
# industry_utilities[T.True]                                             -0.1133      0.072     -1.572      0.116      -0.255       0.028
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.1377      0.026      5.338      0.000       0.087       0.188
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.2146      0.069    -17.515      0.000      -1.350      -1.079
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5464      0.023    -23.691      0.000      -0.592      -0.501
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.5498      0.023    -24.294      0.000      -0.594      -0.505
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0808      0.025     -3.207      0.001      -0.130      -0.031
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                   -0.1518      0.020     -7.690      0.000      -0.190      -0.113
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.5491      0.018    -30.192      0.000      -0.585      -0.513
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.1564      0.017     -8.946      0.000      -0.191      -0.122
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]               0.0818      0.022      3.776      0.000       0.039       0.124
# log_insured_population                                                 -0.0025      0.008     -0.313      0.754      -0.018       0.013
# log_number_of_patents                                                   0.0348      0.009      3.995      0.000       0.018       0.052
# log_enterprise_age                                                     -0.0011      0.007     -0.158      0.874      -0.015       0.013
# double_world_class                                                     -0.1157      0.022     -5.354      0.000      -0.158      -0.073
# log_patent_sq                                                          -0.0289      0.004     -8.220      0.000      -0.036      -0.022
# ==============================================================================
# Omnibus:                     2414.696   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4386.459
# Skew:                          -1.065   Prob(JB):                         0.00
# Kurtosis:                       4.664   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.272
# Model:                                                       OLS   Adj. R-squared:                  0.271
# Method:                                            Least Squares   F-statistic:                     240.2
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:23:59   Log-Likelihood:                -13873.
# No. Observations:                                          14401   AIC:                         2.779e+04
# Df Residuals:                                              14381   BIC:                         2.794e+04
# Df Model:                                                     19
# Covariance Type:                                             HC1
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.2518      0.012    749.731      0.000       9.228       9.276
# industry_agriculture[T.True]                                            0.0007      0.191      0.004      0.997      -0.374       0.375
# industry_other_services[T.True]                                        -0.0924      0.175     -0.529      0.597      -0.435       0.250
# industry_rnd_it[T.True]                                                -0.2170      0.014    -15.898      0.000      -0.244      -0.190
# industry_trade_construction_business[T.True]                           -0.1136      0.020     -5.656      0.000      -0.153      -0.074
# industry_utilities[T.True]                                             -0.1004      0.066     -1.520      0.129      -0.230       0.029
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.0479      0.025      1.947      0.052      -0.000       0.096
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.2002      0.065    -18.528      0.000      -1.327      -1.073
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5852      0.021    -28.115      0.000      -0.626      -0.544
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.6189      0.022    -28.068      0.000      -0.662      -0.576
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0715      0.022     -3.293      0.001      -0.114      -0.029
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                    0.1746      0.021      8.483      0.000       0.134       0.215
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.4287      0.017    -25.520      0.000      -0.462      -0.396
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.0002      0.017     -0.013      0.990      -0.034       0.034
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]              -0.0764      0.021     -3.584      0.000      -0.118      -0.035
# log_insured_population                                                 -0.0021      0.007     -0.276      0.782      -0.017       0.013
# log_number_of_patents                                                   0.0268      0.008      3.291      0.001       0.011       0.043
# log_enterprise_age                                                     -0.0001      0.006     -0.022      0.982      -0.013       0.013
# double_world_class                                                     -0.4800      0.022    -22.260      0.000      -0.522      -0.438
# log_patent_sq                                                          -0.0230      0.003     -7.216      0.000      -0.029      -0.017
# ==============================================================================
# Omnibus:                     2520.296   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5155.506
# Skew:                          -1.050   Prob(JB):                         0.00
# Kurtosis:                       5.044   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
