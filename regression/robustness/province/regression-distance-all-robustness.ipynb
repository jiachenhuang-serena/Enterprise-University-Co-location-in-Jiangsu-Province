# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Statistical tests
from scipy.stats import skew, kurtosis, shapiro

# Coordinate transformation and distance calculation
from pyproj import Transformer
from scipy.spatial.distance import cdist
import math

from statsmodels.stats.diagnostic import het_breuschpagan

# %%
df = pd.read_excel("company-university-2-1.xlsx")

print("Initial data overview:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Initial data overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47644 entries, 0 to 47643
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   number_of_patents                          47644 non-null  int64
#  1   city                                       47644 non-null  object
#  2   county                                     47644 non-null  object
#  3   national_industry_category(GB standard)    47644 non-null  object
#  4   date                                       47644 non-null  object
#  5   insured_population                         47644 non-null  int64
#  6   x_utm                                      47644 non-null  float64
#  7   y_utm                                      47644 non-null  float64
#  8   nearest_university_name                    47644 non-null  object
#  9   nearest_university_distance_m              47644 non-null  float64
#  10  double_world_class                         47644 non-null  int64
#  11  Undergraduate University                   47644 non-null  object
#  12  distance_to_nearest_bachelor_university_m  47644 non-null  float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 4.7+ MB
#
# Missing values:
# number_of_patents                            0
# city                                         0
# county                                       0
# national_industry_category(GB standard)      0
# date                                         0
# insured_population                           0
# x_utm                                        0
# y_utm                                        0
# nearest_university_name                      0
# nearest_university_distance_m                0
# double_world_class                           0
# Undergraduate University                     0
# distance_to_nearest_bachelor_university_m    0
# dtype: int64

# %%
# Convert establishment date to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Calculate firm age in years
today = pd.Timestamp.today()
df['enterprise_age'] = (today - df['date']).dt.days / 365.25

# Display age range
print(f"Firm age computed: range {df['enterprise_age'].min():.1f} ~ {df['enterprise_age'].max():.1f} years")
# Out:
# Firm age computed: range 2.2 ~ 69.2 years

# %%
# Define the order of industry categories with 'Manufacturing' as the baseline (first)
industry_order = [
    'Manufacturing',  # Baseline category
    'Agriculture and Related Activities',
    'Other Services',
    'R&D and IT Services',
    'Trade, Construction, and Business Services',
    'Utilities and Infrastructure'
]

# Convert the industry column to a categorical type with specified order
df['national_industry_category(GB standard)'] = pd.Categorical(
    df['national_industry_category(GB standard)'],
    categories=industry_order,
    ordered=True
)

# Create dummy variables, dropping the first category ('Manufacturing') as the baseline
df = pd.get_dummies(df, columns=['national_industry_category(GB standard)'], drop_first=True)

# Rename dummy variable columns for clarity
df.rename(columns={
    'national_industry_category(GB standard)_Agriculture and Related Activities': 'industry_agriculture',
    'national_industry_category(GB standard)_Other Services': 'industry_other_services',
    'national_industry_category(GB standard)_R&D and IT Services': 'industry_rnd_it',
    'national_industry_category(GB standard)_Trade, Construction, and Business Services': 'industry_trade_construction_business',
    'national_industry_category(GB standard)_Utilities and Infrastructure': 'industry_utilities'
}, inplace=True)

# Define the list of dummy variable columns (excluding the baseline)
industry_cols = [
    'industry_agriculture',
    'industry_other_services',
    'industry_rnd_it',
    'industry_trade_construction_business',
    'industry_utilities'
]

print(f"Industry dummy variables created (baseline = 'Manufacturing'): {industry_cols}")
# Out:
# Industry dummy variables created (baseline = 'Manufacturing'): ['industry_agriculture', 'industry_other_services', 'industry_rnd_it', 'industry_trade_construction_business', 'industry_utilities']

# %%
# Descriptive statistics and correlation
num_vars = [
    'nearest_university_distance_m', 'distance_to_nearest_bachelor_university_m', 'insured_population',
    'number_of_patents', 'enterprise_age'
]

print("\nDescriptive statistics of numerical variables:")
print(df[num_vars].describe())

# Correlation matrix
corr_matrix = df[num_vars].corr()
print("\nCorrelation matrix:")
print(corr_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

corr_matrix.to_csv("correlation_matrix.csv")
# Out:
# Descriptive statistics of numerical variables:
#        nearest_university_distance_m  \
# count                   47644.000000
# mean                     7713.163809
# std                      7136.609796
# min                        14.241553
# 25%                      3035.793330
# 50%                      5879.759698
# 75%                     10036.635773
# max                     67104.606431
#
#        distance_to_nearest_bachelor_university_m  insured_population  \
# count                               47644.000000        47644.000000
# mean                                12108.334516          103.889430
# std                                 11826.250743          524.053524
# min                                    20.146359            1.000000
# 25%                                  4409.712472           12.000000
# 50%                                  9047.015828           30.000000
# 75%                                 14632.290941           77.000000
# max                                 89181.436448        54532.000000
#
#        number_of_patents  enterprise_age
# count       47644.000000    47644.000000
# mean           71.017610       13.589843
# std           273.714543        7.477014
# min             1.000000        2.171116
# 25%            22.000000        7.709788
# 50%            38.000000       11.830253
# 75%            68.000000       18.395619
# max         36808.000000       69.169062
#
# Correlation matrix:
#                                            nearest_university_distance_m  \
# nearest_university_distance_m                                   1.000000
# distance_to_nearest_bachelor_university_m                       0.694184
# insured_population                                             -0.005233
# number_of_patents                                              -0.021799
# enterprise_age                                                  0.015633
#
#                                            distance_to_nearest_bachelor_university_m  \
# nearest_university_distance_m                                               0.694184
# distance_to_nearest_bachelor_university_m                                   1.000000
# insured_population                                                         -0.002455
# number_of_patents                                                          -0.018049
# enterprise_age                                                             -0.006570
#
#                                            insured_population  \
# nearest_university_distance_m                       -0.005233
# distance_to_nearest_bachelor_university_m           -0.002455
# insured_population                                   1.000000
# number_of_patents                                    0.314744
# enterprise_age                                       0.112649
#
#                                            number_of_patents  enterprise_age
# nearest_university_distance_m                      -0.021799        0.015633
# distance_to_nearest_bachelor_university_m          -0.018049       -0.006570
# insured_population                                  0.314744        0.112649
# number_of_patents                                   1.000000        0.125358
# enterprise_age                                      0.125358        1.000000

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['nearest_university_distance_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['nearest_university_distance_m'])
dist_kurt = kurtosis(df['nearest_university_distance_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['nearest_university_distance_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])
    y1_var = "log_nearest_university_distance_m"
else:
    y1_var = "nearest_university_distance_m"
# Out:
# Skewness of `distance`: 2.65
# Kurtosis of `distance`: 10.91
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 47644.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['distance_to_nearest_bachelor_university_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['distance_to_nearest_bachelor_university_m'])
dist_kurt = kurtosis(df['distance_to_nearest_bachelor_university_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['distance_to_nearest_bachelor_university_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])
    y2_var = "log_distance_to_nearest_bachelor_university_m"
else:
    y2_var = "distance_to_nearest_bachelor_university_m"
# Out:
# Skewness of `distance`: 2.31
# Kurtosis of `distance`: 6.72
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 47644.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Define variable list
variables = ['insured_population', 'number_of_patents', 'enterprise_age']

# Plot distributions
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Original distribution
    plt.subplot(3, 2, 2*i+1)
    sns.histplot(df[var].dropna(), bins=30, kde=True)
    plt.title(f"Distribution of {var}")

    # log1p-transformed distribution
    plt.subplot(3, 2, 2*i+2)
    sns.histplot(np.log1p(df[var].dropna()), bins=30, kde=True)
    plt.title(f"Distribution of log1p({var})")

plt.tight_layout()
plt.show()

# %%
# Apply log(1 + x) transformation to reduce skewness and handle zeros safely
df['log_number_of_patents'] = np.log1p(df['number_of_patents'])
df['log_insured_population'] = np.log1p(df['insured_population'])
df['log_enterprise_age'] = np.log1p(df['enterprise_age'])

# %%
# Standardize numerical independent variables
std_vars = [
    'log_insured_population', 'log_number_of_patents', 'log_enterprise_age'
]
scaler = StandardScaler()
df[std_vars] = scaler.fit_transform(df[std_vars])

# %%
# Define y and prepare X for VIF

# Use log-transformed distance as the dependent variable
df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])  # log(1 + x) avoids log(0)
y1 = df['nearest_university_distance_m']  #  this is the new target variable
# Use log-transformed distance as the dependent variable
df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])  # log(1 + x) avoids log(0)
y2 = df['distance_to_nearest_bachelor_university_m']  #  this is the new target variable

# Combine standardized numeric variables and industry dummies
X_vars = std_vars + industry_cols + ['double_world_class']
X = df[X_vars]

# %%
X
# Out:
#        log_insured_population  log_number_of_patents  log_enterprise_age  \
# 0                    1.953837               2.302259           -0.057695
# 1                    2.445224               2.222800            2.152684
# 2                    2.830440               3.902701            1.825576
# 3                    1.879211               3.067179            2.126567
# 4                    2.418014               2.056624            1.752032
# ...                       ...                    ...                 ...
# 47639               -0.904151              -2.658075           -0.399714
# 47640               -1.587366              -2.658075           -0.277513
# 47641               -1.285038              -2.658075           -0.669057
# 47642               -1.587366              -1.946368           -1.285036
# 47643               -2.104197              -2.362690           -1.452153
#
#        industry_agriculture  industry_other_services  industry_rnd_it  \
# 0                     False                    False             True
# 1                     False                    False             True
# 2                     False                    False            False
# 3                     False                    False            False
# 4                     False                    False             True
# ...                     ...                      ...              ...
# 47639                 False                    False             True
# 47640                 False                    False             True
# 47641                 False                    False             True
# 47642                 False                    False             True
# 47643                 False                    False             True
#
#        industry_trade_construction_business  industry_utilities  \
# 0                                     False               False
# 1                                     False               False
# 2                                     False               False
# 3                                     False               False
# 4                                     False               False
# ...                                     ...                 ...
# 47639                                 False               False
# 47640                                 False               False
# 47641                                 False               False
# 47642                                 False               False
# 47643                                 False               False
#
#        double_world_class
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 47639                   0
# 47640                   0
# 47641                   0
# 47642                   0
# 47643                   0
#
# [47644 rows x 9 columns]

# %%
print("\n X column data types:")
print(X.dtypes)
# Out:
#  X column data types:
# log_insured_population                  float64
# log_number_of_patents                   float64
# log_enterprise_age                      float64
# industry_agriculture                       bool
# industry_other_services                    bool
# industry_rnd_it                            bool
# industry_trade_construction_business       bool
# industry_utilities                         bool
# double_world_class                        int64
# dtype: object

# %%
# Construct the squared term of log-transformed number of patents
df['log_patent_sq'] = df['log_number_of_patents'] ** 2

# %%
X_vars = std_vars + industry_cols + ['double_world_class'] + ['log_patent_sq']
X = df[X_vars]

# %%
X = df[X_vars].copy()
X = X.astype(float)

# %%
# VIF calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("\n Variance Inflation Factors (VIF):")
print(vif_df)
# Out:
#  Variance Inflation Factors (VIF):
#                                 feature       VIF
# 0                log_insured_population  1.662138
# 1                 log_number_of_patents  1.737370
# 2                    log_enterprise_age  1.352146
# 3                  industry_agriculture  1.000939
# 4               industry_other_services  1.003548
# 5                       industry_rnd_it  1.383431
# 6  industry_trade_construction_business  1.034176
# 7                    industry_utilities  1.003388
# 8                    double_world_class  1.100259
# 9                         log_patent_sq  1.247006

# %%
# Combine all independent variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define regression formula with city fixed effects
formula1 = 'log_nearest_university_distance_m ~ ' + ' + '.join(all_vars) + ' + C(city , Treatment(reference="NanJing"))'

# Fit the OLS regression model
model1 = smf.ols(formula=formula1, data=df).fit()
print(model1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.218
# Model:                                           OLS   Adj. R-squared:                  0.218
# Method:                                Least Squares   F-statistic:                     603.0
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:02:45   Log-Likelihood:                -58147.
# No. Observations:                              47644   AIC:                         1.163e+05
# Df Residuals:                                  47621   BIC:                         1.165e+05
# Df Model:                                         22
# Covariance Type:                           nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.2127      0.012    661.538      0.000       8.188       8.237
# industry_agriculture[T.True]                              -0.0900      0.103     -0.876      0.381      -0.291       0.111
# industry_other_services[T.True]                           -0.4589      0.096     -4.764      0.000      -0.648      -0.270
# industry_rnd_it[T.True]                                   -0.3893      0.009    -42.888      0.000      -0.407      -0.372
# industry_trade_construction_business[T.True]              -0.2641      0.015    -17.254      0.000      -0.294      -0.234
# industry_utilities[T.True]                                -0.2282      0.042     -5.381      0.000      -0.311      -0.145
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.4572      0.016     28.657      0.000       0.426       0.488
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          0.9457      0.031     30.859      0.000       0.886       1.006
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     0.6711      0.034     19.923      0.000       0.605       0.737
# C(city, Treatment(reference="NanJing"))[T.NanTong]         0.6205      0.017     35.620      0.000       0.586       0.655
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.1515      0.032     36.006      0.000       1.089       1.214
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6353      0.013     50.612      0.000       0.611       0.660
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1444      0.021     53.814      0.000       1.103       1.186
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.5737      0.015     39.153      0.000       0.545       0.602
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          0.4503      0.026     17.596      0.000       0.400       0.500
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.2952      0.020     63.855      0.000       1.255       1.335
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.8066      0.021     37.566      0.000       0.765       0.849
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.5205      0.024     21.331      0.000       0.473       0.568
# log_insured_population                                    -0.0424      0.005     -8.724      0.000      -0.052      -0.033
# log_number_of_patents                                      0.0639      0.005     12.715      0.000       0.054       0.074
# log_enterprise_age                                        -0.0493      0.005    -10.920      0.000      -0.058      -0.040
# double_world_class                                        -0.0125      0.013     -0.976      0.329      -0.037       0.013
# log_patent_sq                                             -0.0498      0.002    -24.611      0.000      -0.054      -0.046
# ==============================================================================
# Omnibus:                     3034.428   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3940.293
# Skew:                          -0.595   Prob(JB):                         0.00
# Kurtosis:                       3.753   Cond. No.                         61.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Combine all explanatory variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define the regression formula
formula2 = 'log_distance_to_nearest_bachelor_university_m ~ ' + ' + '.join(all_vars) + ' + C(city , Treatment(reference="NanJing"))'

# Fit the OLS regression model
model2 = smf.ols(formula=formula2, data=df).fit()
print(model2.summary())
# Out:
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.336
# Model:                                                       OLS   Adj. R-squared:                  0.335
# Method:                                            Least Squares   F-statistic:                     1094.
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:02:55   Log-Likelihood:                -56918.
# No. Observations:                                          47644   AIC:                         1.139e+05
# Df Residuals:                                              47621   BIC:                         1.141e+05
# Df Model:                                                     22
# Covariance Type:                                       nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.4894      0.012    701.698      0.000       8.466       8.513
# industry_agriculture[T.True]                               0.0343      0.100      0.342      0.732      -0.162       0.231
# industry_other_services[T.True]                           -0.5024      0.094     -5.353      0.000      -0.686      -0.318
# industry_rnd_it[T.True]                                   -0.3993      0.009    -45.134      0.000      -0.417      -0.382
# industry_trade_construction_business[T.True]              -0.2831      0.015    -18.979      0.000      -0.312      -0.254
# industry_utilities[T.True]                                -0.2850      0.041     -6.896      0.000      -0.366      -0.204
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.5300      0.016     34.090      0.000       0.500       0.561
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          1.2844      0.030     43.009      0.000       1.226       1.343
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     1.0465      0.033     31.881      0.000       0.982       1.111
# C(city, Treatment(reference="NanJing"))[T.NanTong]         1.1107      0.017     65.430      0.000       1.077       1.144
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.5183      0.031     48.717      0.000       1.457       1.579
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6674      0.012     54.553      0.000       0.643       0.691
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1592      0.021     55.934      0.000       1.119       1.200
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.8411      0.014     58.903      0.000       0.813       0.869
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          1.2674      0.025     50.826      0.000       1.219       1.316
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.7481      0.020     88.439      0.000       1.709       1.787
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.9163      0.021     43.787      0.000       0.875       0.957
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.9483      0.024     39.884      0.000       0.902       0.995
# log_insured_population                                    -0.0361      0.005     -7.621      0.000      -0.045      -0.027
# log_number_of_patents                                      0.0682      0.005     13.934      0.000       0.059       0.078
# log_enterprise_age                                        -0.0559      0.004    -12.724      0.000      -0.065      -0.047
# double_world_class                                        -0.3637      0.012    -29.237      0.000      -0.388      -0.339
# log_patent_sq                                             -0.0469      0.002    -23.755      0.000      -0.051      -0.043
# ==============================================================================
# Omnibus:                     4639.205   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7143.053
# Skew:                          -0.734   Prob(JB):                         0.00
# Kurtosis:                       4.202   Cond. No.                         61.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create side-by-side residual plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Residual plot for distance to any university
axs[0].scatter(model1.fittedvalues, model1.resid, alpha=0.5)
axs[0].axhline(0, color='red')
axs[0].set_title("Residual Plot - Any University")
axs[0].set_xlabel("Fitted Values")
axs[0].set_ylabel("Residuals")

# Residual plot for distance to nearest bachelor-level university
axs[1].scatter(model2.fittedvalues, model2.resid, alpha=0.5)
axs[1].axhline(0, color='red')
axs[1].set_title("Residual Plot - Bachelor-level University")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Residuals")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Extract residuals and design matrix from the model
resid = model1.resid
exog = model1.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 1488.9958
# p-value: 0.0000
# F-statistic: 69.8314
# F p-value: 0.0000

# %%
# Extract residuals and design matrix from the model
resid = model2.resid
exog = model2.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 3237.4608
# p-value: 0.0000
# F-statistic: 157.8096
# F p-value: 0.0000

# %%
model1_robust = model1.get_robustcov_results(cov_type='HC1')
print(model1_robust.summary())

model2_robust = model2.get_robustcov_results(cov_type='HC1')
print(model2_robust.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.218
# Model:                                           OLS   Adj. R-squared:                  0.218
# Method:                                Least Squares   F-statistic:                     507.4
# Date:                               Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       16:03:00   Log-Likelihood:                -58147.
# No. Observations:                              47644   AIC:                         1.163e+05
# Df Residuals:                                  47621   BIC:                         1.165e+05
# Df Model:                                         22
# Covariance Type:                                 HC1
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.2127      0.014    583.683      0.000       8.185       8.240
# industry_agriculture[T.True]                              -0.0900      0.128     -0.705      0.481      -0.340       0.160
# industry_other_services[T.True]                           -0.4589      0.105     -4.369      0.000      -0.665      -0.253
# industry_rnd_it[T.True]                                   -0.3893      0.009    -41.821      0.000      -0.408      -0.371
# industry_trade_construction_business[T.True]              -0.2641      0.016    -16.727      0.000      -0.295      -0.233
# industry_utilities[T.True]                                -0.2282      0.049     -4.678      0.000      -0.324      -0.133
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.4572      0.017     27.376      0.000       0.424       0.490
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          0.9457      0.040     23.561      0.000       0.867       1.024
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     0.6711      0.039     17.000      0.000       0.594       0.748
# C(city, Treatment(reference="NanJing"))[T.NanTong]         0.6205      0.019     32.990      0.000       0.584       0.657
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.1515      0.036     31.809      0.000       1.081       1.222
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6353      0.014     46.195      0.000       0.608       0.662
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1444      0.023     49.793      0.000       1.099       1.189
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.5737      0.015     38.232      0.000       0.544       0.603
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          0.4503      0.029     15.338      0.000       0.393       0.508
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.2952      0.025     52.388      0.000       1.247       1.344
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.8066      0.023     35.638      0.000       0.762       0.851
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.5205      0.025     21.207      0.000       0.472       0.569
# log_insured_population                                    -0.0424      0.005     -8.468      0.000      -0.052      -0.033
# log_number_of_patents                                      0.0639      0.005     12.043      0.000       0.053       0.074
# log_enterprise_age                                        -0.0493      0.005    -10.750      0.000      -0.058      -0.040
# double_world_class                                        -0.0125      0.013     -0.949      0.342      -0.038       0.013
# log_patent_sq                                             -0.0498      0.002    -21.560      0.000      -0.054      -0.045
# ==============================================================================
# Omnibus:                     3034.428   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3940.293
# Skew:                          -0.595   Prob(JB):                         0.00
# Kurtosis:                       3.753   Cond. No.                         61.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.336
# Model:                                                       OLS   Adj. R-squared:                  0.335
# Method:                                            Least Squares   F-statistic:                     934.1
# Date:                                           Sun, 31 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   16:03:00   Log-Likelihood:                -56918.
# No. Observations:                                          47644   AIC:                         1.139e+05
# Df Residuals:                                              47621   BIC:                         1.141e+05
# Df Model:                                                     22
# Covariance Type:                                             HC1
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  8.4894      0.014    616.202      0.000       8.462       8.516
# industry_agriculture[T.True]                               0.0343      0.108      0.316      0.752      -0.178       0.247
# industry_other_services[T.True]                           -0.5024      0.104     -4.830      0.000      -0.706      -0.299
# industry_rnd_it[T.True]                                   -0.3993      0.009    -43.578      0.000      -0.417      -0.381
# industry_trade_construction_business[T.True]              -0.2831      0.016    -18.071      0.000      -0.314      -0.252
# industry_utilities[T.True]                                -0.2850      0.050     -5.687      0.000      -0.383      -0.187
# C(city, Treatment(reference="NanJing"))[T.ChangZhou]       0.5300      0.016     33.356      0.000       0.499       0.561
# C(city, Treatment(reference="NanJing"))[T.HuaiAn]          1.2844      0.035     36.236      0.000       1.215       1.354
# C(city, Treatment(reference="NanJing"))[T.LianYunGang]     1.0465      0.048     21.913      0.000       0.953       1.140
# C(city, Treatment(reference="NanJing"))[T.NanTong]         1.1107      0.020     54.947      0.000       1.071       1.150
# C(city, Treatment(reference="NanJing"))[T.SuQian]          1.5183      0.036     42.664      0.000       1.449       1.588
# C(city, Treatment(reference="NanJing"))[T.SuZhou]          0.6674      0.013     49.992      0.000       0.641       0.694
# C(city, Treatment(reference="NanJing"))[T.TaiZhou]         1.1592      0.023     49.408      0.000       1.113       1.205
# C(city, Treatment(reference="NanJing"))[T.WuXi]            0.8411      0.014     61.863      0.000       0.814       0.868
# C(city, Treatment(reference="NanJing"))[T.XuZhou]          1.2674      0.038     33.366      0.000       1.193       1.342
# C(city, Treatment(reference="NanJing"))[T.YanCheng]        1.7481      0.022     79.735      0.000       1.705       1.791
# C(city, Treatment(reference="NanJing"))[T.YangZhou]        0.9163      0.023     39.728      0.000       0.871       0.961
# C(city, Treatment(reference="NanJing"))[T.ZhenJiang]       0.9483      0.024     39.797      0.000       0.902       0.995
# log_insured_population                                    -0.0361      0.005     -7.286      0.000      -0.046      -0.026
# log_number_of_patents                                      0.0682      0.005     12.783      0.000       0.058       0.079
# log_enterprise_age                                        -0.0559      0.005    -12.373      0.000      -0.065      -0.047
# double_world_class                                        -0.3637      0.013    -28.484      0.000      -0.389      -0.339
# log_patent_sq                                             -0.0469      0.002    -20.729      0.000      -0.051      -0.042
# ==============================================================================
# Omnibus:                     4639.205   Durbin-Watson:                   1.931
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7143.053
# Skew:                          -0.734   Prob(JB):                         0.00
# Kurtosis:                       4.202   Cond. No.                         61.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
