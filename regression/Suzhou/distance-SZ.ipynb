# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Statistical modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Preprocessing
from sklearn.preprocessing import StandardScaler

# Statistical tests
from scipy.stats import skew, kurtosis, shapiro

# Coordinate transformation and distance calculation
from pyproj import Transformer
from scipy.spatial.distance import cdist
import math

from statsmodels.stats.diagnostic import het_breuschpagan

# %%
df = pd.read_excel("company-university-SZ.xlsx")

print("Initial data overview:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Initial data overview:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14920 entries, 0 to 14919
# Data columns (total 13 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   number_of_patents                          14920 non-null  int64
#  1   city                                       14920 non-null  object
#  2   county                                     14920 non-null  object
#  3   national_industry_category(GB standard)    14920 non-null  object
#  4   date                                       14920 non-null  object
#  5   insured_population                         14920 non-null  int64
#  6   x_utm                                      14920 non-null  float64
#  7   y_utm                                      14920 non-null  float64
#  8   nearest_university_name                    14920 non-null  object
#  9   nearest_university_distance_m              14920 non-null  float64
#  10  double_world_class                         14920 non-null  int64
#  11  Undergraduate University                   14920 non-null  object
#  12  distance_to_nearest_bachelor_university_m  14920 non-null  float64
# dtypes: float64(4), int64(3), object(6)
# memory usage: 1.5+ MB
#
# Missing values:
# number_of_patents                            0
# city                                         0
# county                                       0
# national_industry_category(GB standard)      0
# date                                         0
# insured_population                           0
# x_utm                                        0
# y_utm                                        0
# nearest_university_name                      0
# nearest_university_distance_m                0
# double_world_class                           0
# Undergraduate University                     0
# distance_to_nearest_bachelor_university_m    0
# dtype: int64

# %%
# Convert establishment date to datetime format
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# Calculate firm age in years
today = pd.Timestamp.today()
df['enterprise_age'] = (today - df['date']).dt.days / 365.25

# Display age range
print(f"Firm age computed: range {df['enterprise_age'].min():.1f} ~ {df['enterprise_age'].max():.1f} years")
# Out:
# Firm age computed: range 2.2 ~ 45.5 years

# %%
# Define the order of industry categories with 'Manufacturing' as the baseline (first)
industry_order = [
    'Manufacturing',  # Baseline category
    'Agriculture and Related Activities',
    'Other Services',
    'R&D and IT Services',
    'Trade, Construction, and Business Services',
    'Utilities and Infrastructure'
]

# Convert the industry column to a categorical type with specified order
df['national_industry_category(GB standard)'] = pd.Categorical(
    df['national_industry_category(GB standard)'],
    categories=industry_order,
    ordered=True
)

# Create dummy variables, dropping the first category ('Manufacturing') as the baseline
df = pd.get_dummies(df, columns=['national_industry_category(GB standard)'], drop_first=True)

# Rename dummy variable columns for clarity
df.rename(columns={
    'national_industry_category(GB standard)_Agriculture and Related Activities': 'industry_agriculture',
    'national_industry_category(GB standard)_Other Services': 'industry_other_services',
    'national_industry_category(GB standard)_R&D and IT Services': 'industry_rnd_it',
    'national_industry_category(GB standard)_Trade, Construction, and Business Services': 'industry_trade_construction_business',
    'national_industry_category(GB standard)_Utilities and Infrastructure': 'industry_utilities'
}, inplace=True)

# Define the list of dummy variable columns (excluding the baseline)
industry_cols = [
    'industry_agriculture',
    'industry_other_services',
    'industry_rnd_it',
    'industry_trade_construction_business',
    'industry_utilities'
]

print(f"Industry dummy variables created (baseline = 'Manufacturing'): {industry_cols}")
# Out:
# Industry dummy variables created (baseline = 'Manufacturing'): ['industry_agriculture', 'industry_other_services', 'industry_rnd_it', 'industry_trade_construction_business', 'industry_utilities']

# %%
# Descriptive statistics and correlation
num_vars = [
    'nearest_university_distance_m', 'distance_to_nearest_bachelor_university_m', 'insured_population',
    'number_of_patents', 'enterprise_age'
]

print("\nDescriptive statistics of numerical variables:")
print(df[num_vars].describe())

# Correlation matrix
corr_matrix = df[num_vars].corr()
print("\nCorrelation matrix:")
print(corr_matrix)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

corr_matrix.to_csv("correlation_matrix.csv")
# Out:
# Descriptive statistics of numerical variables:
#        nearest_university_distance_m  \
# count                   14920.000000
# mean                     7058.874213
# std                      4220.410636
# min                        44.301665
# 25%                      3632.697492
# 50%                      6558.065025
# 75%                      9925.249771
# max                     20529.818040
#
#        distance_to_nearest_bachelor_university_m  insured_population  \
# count                               14920.000000        14920.000000
# mean                                 9284.545285          107.892560
# std                                  5809.458194          696.682845
# min                                    44.301665            0.000000
# 25%                                  4765.794624           12.000000
# 50%                                  8501.875474           28.000000
# 75%                                 12311.292202           75.000000
# max                                 35215.950403        54532.000000
#
#        number_of_patents  enterprise_age
# count       14920.000000    14920.000000
# mean           75.473391       12.779237
# std           390.492973        6.828747
# min             0.000000        2.239562
# 25%            21.000000        7.550308
# 50%            37.000000       11.154004
# 75%            67.000000       17.002053
# max         36808.000000       45.519507
#
# Correlation matrix:
#                                            nearest_university_distance_m  \
# nearest_university_distance_m                                   1.000000
# distance_to_nearest_bachelor_university_m                       0.770100
# insured_population                                              0.007346
# number_of_patents                                              -0.007203
# enterprise_age                                                  0.087332
#
#                                            distance_to_nearest_bachelor_university_m  \
# nearest_university_distance_m                                               0.770100
# distance_to_nearest_bachelor_university_m                                   1.000000
# insured_population                                                          0.003371
# number_of_patents                                                          -0.006523
# enterprise_age                                                              0.065830
#
#                                            insured_population  \
# nearest_university_distance_m                        0.007346
# distance_to_nearest_bachelor_university_m            0.003371
# insured_population                                   1.000000
# number_of_patents                                    0.270663
# enterprise_age                                       0.119387
#
#                                            number_of_patents  enterprise_age
# nearest_university_distance_m                      -0.007203        0.087332
# distance_to_nearest_bachelor_university_m          -0.006523        0.065830
# insured_population                                  0.270663        0.119387
# number_of_patents                                   1.000000        0.105515
# enterprise_age                                      0.105515        1.000000

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['nearest_university_distance_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['nearest_university_distance_m'])
dist_kurt = kurtosis(df['nearest_university_distance_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['nearest_university_distance_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])
    y1_var = "log_nearest_university_distance_m"
else:
    y1_var = "nearest_university_distance_m"
# Out:
# Skewness of `distance`: 0.58
# Kurtosis of `distance`: -0.32
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 14920.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Target variable distribution
plt.figure()
sns.histplot(df['distance_to_nearest_bachelor_university_m'], kde=True, bins=30)
plt.title("Distribution of Distance")
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.show()

dist_skew = skew(df['distance_to_nearest_bachelor_university_m'])
dist_kurt = kurtosis(df['distance_to_nearest_bachelor_university_m'])
print(f"\nSkewness of `distance`: {dist_skew:.2f}")
print(f"Kurtosis of `distance`: {dist_kurt:.2f}")

stat, p_value = shapiro(df['distance_to_nearest_bachelor_university_m'])
print(f"Shapiro-Wilk test p-value: {p_value:.4f}")
if p_value < 0.05:
    print("Warning: `distance` deviates from normality. Consider log-transform.")
    df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])
    y2_var = "log_distance_to_nearest_bachelor_university_m"
else:
    y2_var = "distance_to_nearest_bachelor_university_m"
# Out:
# Skewness of `distance`: 1.03
# Kurtosis of `distance`: 1.20
# Shapiro-Wilk test p-value: 0.0000
# Warning: `distance` deviates from normality. Consider log-transform.
# D:\anaconda0804\Lib\site-packages\scipy\stats\_axis_nan_policy.py:586: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 14920.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Define variable list
variables = ['insured_population', 'number_of_patents', 'enterprise_age']

# Plot distributions
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Original distribution
    plt.subplot(3, 2, 2*i+1)
    sns.histplot(df[var].dropna(), bins=30, kde=True)
    plt.title(f"Distribution of {var}")

    # log1p-transformed distribution
    plt.subplot(3, 2, 2*i+2)
    sns.histplot(np.log1p(df[var].dropna()), bins=30, kde=True)
    plt.title(f"Distribution of log1p({var})")

plt.tight_layout()
plt.show()

# %%
# Apply log(1 + x) transformation to reduce skewness and handle zeros safely
df['log_number_of_patents'] = np.log1p(df['number_of_patents'])
df['log_insured_population'] = np.log1p(df['insured_population'])
df['log_enterprise_age'] = np.log1p(df['enterprise_age'])

# %%
# Standardize numerical independent variables
std_vars = [
    'log_insured_population', 'log_number_of_patents', 'log_enterprise_age'
]
scaler = StandardScaler()
df[std_vars] = scaler.fit_transform(df[std_vars])

# %%
# Define y and prepare X for VIF

# Use log-transformed distance as the dependent variable
df['log_nearest_university_distance_m'] = np.log1p(df['nearest_university_distance_m'])  # log(1 + x) avoids log(0)
y1 = df['nearest_university_distance_m']  #  this is the new target variable
# Use log-transformed distance as the dependent variable
df['log_distance_to_nearest_bachelor_university_m'] = np.log1p(df['distance_to_nearest_bachelor_university_m'])  # log(1 + x) avoids log(0)
y2 = df['distance_to_nearest_bachelor_university_m']  #  this is the new target variable

# Combine standardized numeric variables and industry dummies
X_vars = std_vars + industry_cols + ['double_world_class']
X = df[X_vars]

# %%
X
# Out:
#        log_insured_population  log_number_of_patents  log_enterprise_age  \
# 0                    1.898070               2.143737            0.028736
# 1                    2.364273               2.071170            2.323998
# 2                    2.729746               3.605358            1.984772
# 3                    1.827270               2.842309            2.296917
# 4                    2.338457               1.919407            1.908488
# ...                       ...                    ...                 ...
# 14915               -2.442325              -3.416533           -1.416713
# 14916               -2.442325              -3.416533           -2.148654
# 14917               -0.971295              -3.416533           -0.782038
# 14918               -0.971295              -3.416533           -0.938179
# 14919               -2.442325              -3.416533           -1.653736
#
#        industry_agriculture  industry_other_services  industry_rnd_it  \
# 0                     False                    False             True
# 1                     False                    False             True
# 2                     False                    False            False
# 3                     False                    False            False
# 4                     False                    False             True
# ...                     ...                      ...              ...
# 14915                 False                    False             True
# 14916                 False                    False             True
# 14917                 False                    False             True
# 14918                 False                    False             True
# 14919                 False                    False             True
#
#        industry_trade_construction_business  industry_utilities  \
# 0                                     False               False
# 1                                     False               False
# 2                                     False               False
# 3                                     False               False
# 4                                     False               False
# ...                                     ...                 ...
# 14915                                 False               False
# 14916                                 False               False
# 14917                                 False               False
# 14918                                 False               False
# 14919                                 False               False
#
#        double_world_class
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       1
# ...                   ...
# 14915                   0
# 14916                   0
# 14917                   1
# 14918                   0
# 14919                   0
#
# [14920 rows x 9 columns]

# %%
print("\n X column data types:")
print(X.dtypes)
# Out:
#  X column data types:
# log_insured_population                  float64
# log_number_of_patents                   float64
# log_enterprise_age                      float64
# industry_agriculture                       bool
# industry_other_services                    bool
# industry_rnd_it                            bool
# industry_trade_construction_business       bool
# industry_utilities                         bool
# double_world_class                        int64
# dtype: object

# %%
# Construct the squared term of log-transformed number of patents
df['log_patent_sq'] = df['log_number_of_patents'] ** 2

# %%
X_vars = std_vars + industry_cols + ['double_world_class'] + ['log_patent_sq']
X = df[X_vars]

# %%
X = df[X_vars].copy()
X = X.astype(float)

# %%
# VIF calculation
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_df = pd.DataFrame()
vif_df["feature"] = X.columns
vif_df["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("\n Variance Inflation Factors (VIF):")
print(vif_df)
# Out:
#  Variance Inflation Factors (VIF):
#                                 feature       VIF
# 0                log_insured_population  1.691261
# 1                 log_number_of_patents  1.742082
# 2                    log_enterprise_age  1.417385
# 3                  industry_agriculture  1.000750
# 4               industry_other_services  1.010574
# 5                       industry_rnd_it  1.375606
# 6  industry_trade_construction_business  1.032115
# 7                    industry_utilities  1.002984
# 8                    double_world_class  1.078604
# 9                         log_patent_sq  1.256190

# %%
# Combine all independent variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define regression formula with city fixed effects
formula1 = 'log_nearest_university_distance_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="KunShan"))'

# Fit the OLS regression model
model1 = smf.ols(formula=formula1, data=df).fit()
print(model1.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.216
# Model:                                           OLS   Adj. R-squared:                  0.215
# Method:                                Least Squares   F-statistic:                     215.6
# Date:                               Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       10:58:00   Log-Likelihood:                -15390.
# No. Observations:                              14920   AIC:                         3.082e+04
# Df Residuals:                                  14900   BIC:                         3.097e+04
# Df Model:                                         19
# Covariance Type:                           nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.0000      0.013    678.654      0.000       8.974       9.026
# industry_agriculture[T.True]                                           -0.2843      0.257     -1.106      0.269      -0.788       0.219
# industry_other_services[T.True]                                        -0.3273      0.143     -2.295      0.022      -0.607      -0.048
# industry_rnd_it[T.True]                                                -0.2758      0.014    -19.583      0.000      -0.303      -0.248
# industry_trade_construction_business[T.True]                           -0.1480      0.021     -6.917      0.000      -0.190      -0.106
# industry_utilities[T.True]                                             -0.0994      0.068     -1.458      0.145      -0.233       0.034
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.1317      0.022      5.907      0.000       0.088       0.175
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.1808      0.058    -20.188      0.000      -1.295      -1.066
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5522      0.023    -24.072      0.000      -0.597      -0.507
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.5577      0.021    -26.127      0.000      -0.600      -0.516
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0799      0.024     -3.402      0.001      -0.126      -0.034
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                   -0.1731      0.022     -7.900      0.000      -0.216      -0.130
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.5471      0.020    -26.898      0.000      -0.587      -0.507
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.1531      0.022     -7.048      0.000      -0.196      -0.110
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]               0.0858      0.024      3.646      0.000       0.040       0.132
# log_insured_population                                                  0.0046      0.007      0.625      0.532      -0.010       0.019
# log_number_of_patents                                                   0.0300      0.007      4.037      0.000       0.015       0.044
# log_enterprise_age                                                     -0.0013      0.007     -0.196      0.844      -0.015       0.012
# double_world_class                                                     -0.1088      0.020     -5.389      0.000      -0.148      -0.069
# log_patent_sq                                                          -0.0293      0.003    -10.765      0.000      -0.035      -0.024
# ==============================================================================
# Omnibus:                     2418.448   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4292.681
# Skew:                          -1.045   Prob(JB):                         0.00
# Kurtosis:                       4.592   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Combine all explanatory variables
all_vars = std_vars + industry_cols + ['double_world_class', 'log_patent_sq']

# Define the regression formula
formula2 = 'log_distance_to_nearest_bachelor_university_m ~ ' + ' + '.join(all_vars) + ' + C(county , Treatment(reference="KunShan"))'

# Fit the OLS regression model
model2 = smf.ols(formula=formula2, data=df).fit()
print(model2.summary())
# Out:
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.280
# Model:                                                       OLS   Adj. R-squared:                  0.279
# Method:                                            Least Squares   F-statistic:                     304.2
# Date:                                           Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   11:01:25   Log-Likelihood:                -14462.
# No. Observations:                                          14920   AIC:                         2.896e+04
# Df Residuals:                                              14900   BIC:                         2.912e+04
# Df Model:                                                     19
# Covariance Type:                                       nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.2536      0.012    742.557      0.000       9.229       9.278
# industry_agriculture[T.True]                                           -0.0038      0.241     -0.016      0.988      -0.477       0.470
# industry_other_services[T.True]                                        -0.0974      0.134     -0.727      0.467      -0.360       0.165
# industry_rnd_it[T.True]                                                -0.2184      0.013    -16.499      0.000      -0.244      -0.192
# industry_trade_construction_business[T.True]                           -0.1150      0.020     -5.722      0.000      -0.154      -0.076
# industry_utilities[T.True]                                             -0.0892      0.064     -1.392      0.164      -0.215       0.036
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.0355      0.021      1.694      0.090      -0.006       0.077
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.1743      0.055    -21.366      0.000      -1.282      -1.067
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5934      0.022    -27.529      0.000      -0.636      -0.551
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.6312      0.020    -31.470      0.000      -0.671      -0.592
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0694      0.022     -3.140      0.002      -0.113      -0.026
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                    0.1827      0.021      8.876      0.000       0.142       0.223
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.4339      0.019    -22.703      0.000      -0.471      -0.396
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.0033      0.020     -0.164      0.870      -0.043       0.037
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]              -0.0797      0.022     -3.606      0.000      -0.123      -0.036
# log_insured_population                                                 -0.0049      0.007     -0.720      0.471      -0.018       0.009
# log_number_of_patents                                                   0.0271      0.007      3.888      0.000       0.013       0.041
# log_enterprise_age                                                      0.0007      0.006      0.105      0.917      -0.012       0.013
# double_world_class                                                     -0.4815      0.019    -25.381      0.000      -0.519      -0.444
# log_patent_sq                                                          -0.0235      0.003     -9.181      0.000      -0.029      -0.018
# ==============================================================================
# Omnibus:                     2609.677   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5326.912
# Skew:                          -1.051   Prob(JB):                         0.00
# Kurtosis:                       5.037   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create side-by-side residual plots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Residual plot for distance to any university
axs[0].scatter(model1.fittedvalues, model1.resid, alpha=0.5)
axs[0].axhline(0, color='red')
axs[0].set_title("Residual Plot - Any University")
axs[0].set_xlabel("Fitted Values")
axs[0].set_ylabel("Residuals")

# Residual plot for distance to nearest bachelor-level university
axs[1].scatter(model2.fittedvalues, model2.resid, alpha=0.5)
axs[1].axhline(0, color='red')
axs[1].set_title("Residual Plot - Bachelor-level University")
axs[1].set_xlabel("Fitted Values")
axs[1].set_ylabel("Residuals")

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Extract residuals and design matrix from the model
resid = model1.resid
exog = model1.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 839.3696
# p-value: 0.0000
# F-statistic: 46.7481
# F p-value: 0.0000

# %%
# Extract residuals and design matrix from the model
resid = model2.resid
exog = model2.model.exog  # Matrix of explanatory variables

# Perform the Breusch-Pagan test
bp_test = het_breuschpagan(resid, exog)

# Print test results
bp_labels = ['Lagrange Multiplier statistic', 'p-value', 'F-statistic', 'F p-value']
for name, value in zip(bp_labels, bp_test):
    print(f"{name}: {value:.4f}")
# Out:
# Lagrange Multiplier statistic: 737.6815
# p-value: 0.0000
# F-statistic: 40.7901
# F p-value: 0.0000

# %%
model1_robust = model1.get_robustcov_results(cov_type='HC1')
print(model1_robust.summary())

model2_robust = model2.get_robustcov_results(cov_type='HC1')
print(model2_robust.summary())
# Out:
#                                     OLS Regression Results
# =============================================================================================
# Dep. Variable:     log_nearest_university_distance_m   R-squared:                       0.216
# Model:                                           OLS   Adj. R-squared:                  0.215
# Method:                                Least Squares   F-statistic:                     204.3
# Date:                               Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                       11:02:09   Log-Likelihood:                -15390.
# No. Observations:                              14920   AIC:                         3.082e+04
# Df Residuals:                                  14900   BIC:                         3.097e+04
# Df Model:                                         19
# Covariance Type:                                 HC1
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.0000      0.011    818.646      0.000       8.978       9.022
# industry_agriculture[T.True]                                           -0.2843      0.421     -0.674      0.500      -1.110       0.542
# industry_other_services[T.True]                                        -0.3273      0.189     -1.733      0.083      -0.698       0.043
# industry_rnd_it[T.True]                                                -0.2758      0.014    -19.093      0.000      -0.304      -0.247
# industry_trade_construction_business[T.True]                           -0.1480      0.020     -7.248      0.000      -0.188      -0.108
# industry_utilities[T.True]                                             -0.0994      0.071     -1.404      0.160      -0.238       0.039
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.1317      0.026      5.114      0.000       0.081       0.182
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.1808      0.066    -17.957      0.000      -1.310      -1.052
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5522      0.023    -24.277      0.000      -0.597      -0.508
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.5577      0.022    -24.936      0.000      -0.602      -0.514
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0799      0.025     -3.213      0.001      -0.129      -0.031
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                   -0.1731      0.020     -8.823      0.000      -0.212      -0.135
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.5471      0.018    -30.458      0.000      -0.582      -0.512
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.1531      0.017     -8.862      0.000      -0.187      -0.119
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]               0.0858      0.021      4.023      0.000       0.044       0.128
# log_insured_population                                                  0.0046      0.008      0.596      0.551      -0.010       0.020
# log_number_of_patents                                                   0.0300      0.008      3.593      0.000       0.014       0.046
# log_enterprise_age                                                     -0.0013      0.007     -0.195      0.846      -0.015       0.012
# double_world_class                                                     -0.1088      0.021     -5.131      0.000      -0.150      -0.067
# log_patent_sq                                                          -0.0293      0.003     -9.051      0.000      -0.036      -0.023
# ==============================================================================
# Omnibus:                     2418.448   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4292.681
# Skew:                          -1.045   Prob(JB):                         0.00
# Kurtosis:                       4.592   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
#                                           OLS Regression Results
# =========================================================================================================
# Dep. Variable:     log_distance_to_nearest_bachelor_university_m   R-squared:                       0.280
# Model:                                                       OLS   Adj. R-squared:                  0.279
# Method:                                            Least Squares   F-statistic:                     260.9
# Date:                                           Thu, 07 Aug 2025   Prob (F-statistic):               0.00
# Time:                                                   11:02:09   Log-Likelihood:                -14462.
# No. Observations:                                          14920   AIC:                         2.896e+04
# Df Residuals:                                              14900   BIC:                         2.912e+04
# Df Model:                                                     19
# Covariance Type:                                             HC1
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                               9.2536      0.012    762.115      0.000       9.230       9.277
# industry_agriculture[T.True]                                           -0.0038      0.190     -0.020      0.984      -0.377       0.369
# industry_other_services[T.True]                                        -0.0974      0.139     -0.703      0.482      -0.369       0.174
# industry_rnd_it[T.True]                                                -0.2184      0.013    -16.227      0.000      -0.245      -0.192
# industry_trade_construction_business[T.True]                           -0.1150      0.020     -5.847      0.000      -0.154      -0.076
# industry_utilities[T.True]                                             -0.0892      0.065     -1.377      0.169      -0.216       0.038
# C(county, Treatment(reference="KunShan"))[T.ChangShu]                   0.0355      0.025      1.435      0.151      -0.013       0.084
# C(county, Treatment(reference="KunShan"))[T.GuSu]                      -1.1743      0.061    -19.277      0.000      -1.294      -1.055
# C(county, Treatment(reference="KunShan"))[T.HuQiu]                     -0.5934      0.021    -28.929      0.000      -0.634      -0.553
# C(county, Treatment(reference="KunShan"))[T.Suzhou Industrial Park]    -0.6312      0.022    -28.892      0.000      -0.674      -0.588
# C(county, Treatment(reference="KunShan"))[T.TaiCang]                   -0.0694      0.021     -3.261      0.001      -0.111      -0.028
# C(county, Treatment(reference="KunShan"))[T.WuJiang]                    0.1827      0.020      9.077      0.000       0.143       0.222
# C(county, Treatment(reference="KunShan"))[T.WuZhong]                   -0.4339      0.017    -26.199      0.000      -0.466      -0.401
# C(county, Treatment(reference="KunShan"))[T.XiangCheng]                -0.0033      0.017     -0.195      0.845      -0.037       0.030
# C(county, Treatment(reference="KunShan"))[T.ZhangJiaGang]              -0.0797      0.021     -3.801      0.000      -0.121      -0.039
# log_insured_population                                                 -0.0049      0.007     -0.698      0.485      -0.019       0.009
# log_number_of_patents                                                   0.0271      0.008      3.535      0.000       0.012       0.042
# log_enterprise_age                                                      0.0007      0.006      0.105      0.916      -0.012       0.013
# double_world_class                                                     -0.4815      0.021    -22.723      0.000      -0.523      -0.440
# log_patent_sq                                                          -0.0235      0.003     -7.927      0.000      -0.029      -0.018
# ==============================================================================
# Omnibus:                     2609.677   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5326.912
# Skew:                          -1.051   Prob(JB):                         0.00
# Kurtosis:                       5.037   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC1)
